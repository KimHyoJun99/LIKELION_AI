# %% [markdown]
# # Visualization_basic

# %% [markdown]
# ### 1. plot

# %%
import csv

data = r"C:\Users\jjjun_ii\Documents\GitHub\LIKELION_AI\Data_TIL\Data_practice\data\seoul.csv"

with open(data, encoding="cp949") as infile:
    reader = csv.reader(infile)
    datas = []
    for data in reader:
        datas.append(data)

# %%
datas
# Out:
# [['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)'],
#  ['1907-10-01', '108', '13.5', '7.9', '20.7'],
#  ['1907-10-02', '108', '16.2', '7.9', '22'],
#  ['1907-10-03', '108', '16.2', '13.1', '21.3'],
#  ['1907-10-04', '108', '16.5', '11.2', '22'],
#  ['1907-10-05', '108', '17.6', '10.9', '25.4'],
#  ['1907-10-06', '108', '13', '11.2', '21.3'],
#  ['1907-10-07', '108', '11.3', '6.3', '16.1'],
#  ['1907-10-08', '108', '8.9', '3.9', '14.9'],
#  ['1907-10-09', '108', '11.6', '3.8', '21.1'],
#  ['1907-10-10', '108', '14.2', '6.4', '24.1'],
#  ['1907-10-11', '108', '15.4', '10.1', '20.4'],
#  ['1907-10-12', '108', '13.9', '11.1', '17.4'],
#  ['1907-10-13', '108', '13.8', '8.3', '21.3'],
#  ['1907-10-14', '108', '13', '6.1', '20.6'],
#  ['1907-10-15', '108', '13.1', '5.7', '20.9'],
#  ['1907-10-16', '108', '14.1', '8.2', '20.2'],
#  ['1907-10-17', '108', '16.4', '10.3', '21.6'],
#  ['1907-10-18', '108', '14.3', '9.8', '20.9'],
#  ['1907-10-19', '108', '13.9', '6.7', '21.3'],
# ...

# %%
high_temp = []
for i in range(1, len(datas)):
    if datas[i][-1] != '':
        high_temp.append(float(datas[i][-1]))  # ''처럼 빈 리스트는 float으로 변경 X
print(high_temp)
# Out:
# [20.7, 22.0, 21.3, 22.0, 25.4, 21.3, 16.1, 14.9, 21.1, 24.1, 20.4, 17.4, 21.3, 20.6, 20.9, 20.2, 21.6, 20.9, 21.3, 22.7, 19.9, 19.6, 16.3, 17.1, 18.7, 18.2, 20.7, 19.6, 20.0, 20.1, 20.3, 21.3, 21.1, 11.1, 13.6, 17.0, 18.1, 12.4, 9.4, 11.9, 13.2, 13.4, 14.9, 16.4, 15.2, 17.6, 12.6, 11.7, 6.7, 4.3, 7.1, 6.2, 11.2, 9.9, 5.9, -0.7, 1.5, 1.9, 2.0, 2.9, -2.4, 1.4, 3.4, 6.1, 1.3, 2.6, 5.8, 1.9, 6.6, 8.1, 4.3, 0.6, 3.8, 9.0, 6.4, -5.1, -2.4, -2.1, -0.4, -0.2, 1.9, -8.1, -10.2, -9.4, 0.9, 6.8, 6.4, -0.7, -1.9, -4.4, -6.1, -2.1, -1.3, -3.0, -2.9, -1.7, -0.1, 2.9, -1.2, -0.9, 2.0, 3.3, 4.8, 4.5, 4.7, 0.1, 0.9, -4.5, -3.6, 2.8, 2.8, 2.3, -6.1, -5.1, -2.7, 0.1, 0.3, -0.6, 0.0, -1.3, 0.8, 0.8, 6.2, 1.6, -0.2, -5.4, -4.1, -5.5, -5.7, -3.7, 1.3, -4.1, -2.5, -2.8, -1.2, 1.3, 2.3, 2.0, -1.4, -1.6, 0.3, 5.5, 7.3, 5.1, 5.4, 2.7, 1.7, 0.8, 4.1, 8.4, 6.3, 5.6, 4.0, 0.1, 4.9, 4.0, 7.9, 7.9, 2.2, 1.9, 1.5, 1.5, 1.8, 2.6, 3.8, 6.7, 11.8, 13.5, 15.7, 10.7, 7.9, 4.3, 6.0, 12.5, 17.0, 14.7, 11.4, 7.4, 8.0, 15.5
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(high_temp)
plt.show()

# %%
date = '1907-10-1'
date_li = date.split('-')
for date in date_li:
    print(date)
# Out:
# 1907
# 10
# 1

# %%
high_temp_08 = []
for i in range(1, len(datas)):
    if datas[i][-1] != '':
        if datas[i][0].split('-')[1] == "08":
            high_temp_08.append(float(datas[i][-1]))

# %%
plt.plot(high_temp_08)
plt.show()

# %%
high_temp_02_14 = []
for i in range(1, len(datas)):
    if datas[i][-1] != '':
        if (datas[i][0].split('-')[1] == '02') and (datas[i][0].split('-')[2] == '14'):
            high_temp_02_14.append(float(datas[i][-1]))
print(high_temp_02_14)
# Out:
# [2.3, 8.8, 2.8, 3.5, 11.2, 3.7, 6.5, -2.9, -1.3, 1.2, 5.5, 6.4, 1.3, 5.1, 7.0, 9.4, 3.5, 6.0, 5.5, 2.6, 4.7, -1.3, 7.7, 2.1, 7.2, 0.7, -0.9, 5.4, 2.6, -2.1, 4.9, 5.3, 2.2, -0.1, -6.9, 5.3, -2.5, 5.5, 4.4, -0.1, 8.5, 0.4, 3.3, 10.5, 6.4, 5.3, 0.9, 2.0, 3.8, 3.0, -4.4, 0.5, 4.7, -2.6, 0.8, 7.5, -2.7, 4.0, 4.6, 5.1, 5.2, 1.4, 6.4, 7.1, 7.9, 14.5, -2.2, -4.1, 1.4, -1.3, 11.7, 6.8, 1.2, 2.0, 1.9, 3.4, 2.5, 2.9, 10.6, 8.6, 12.0, 4.9, 7.8, 6.0, 4.2, 10.8, 6.7, 5.9, 0.4, 3.5, -0.1, 5.8, 7.5, 6.8, 5.5, 7.5, 4.0, 2.7, 5.3, 1.2, -0.2, 8.3, 5.2, 7.6, 6.6, 5.8, 6.5, 8.7]

# %%
plt.plot(high_temp_02_14)
plt.show()

# %%
high_temp_over_1983 = []
low_temp_over_1983 = []
for i in range(1, len(datas)):
    if (datas[i][-1] != '') and (datas[i][-2] != ''):
        if int(datas[i][0].split('-')[0]) > 1983:
            high_temp_over_1983.append(float(datas[i][-1]))
            low_temp_over_1983.append(float(datas[i][-2]))

# %%
plt.plot(high_temp_over_1983)
plt.plot(low_temp_over_1983)
plt.show()

# %% [markdown]
# ### 2. hist

# %%
plt.hist(high_temp_over_1983, bins=100)
plt.show()

# %%
high_temp_01 = []
high_temp_08 = []

for i in range(1, len(datas)):
    if (datas[i][-1] != ''):
        if datas[i][0].split('-')[1] == '01':
            high_temp_01.append(float(datas[i][-1]))
        if datas[i][0].split('-')[1] == '08':
            high_temp_08.append(float(datas[i][-1]))

# %%
plt.hist(high_temp_01, bins=100, label="Jan")
plt.hist(high_temp_08, bins=100, label="Aug")
plt.legend()
plt.show()

# %% [markdown]
# ### 3. boxplot
# [boxplot 구성요소]
# - Q3 - Q1 => IQR 사분범위
# - 이상점: 1.5 * IQR
# - 극단점: 3 * IQR
#
# ![image.png](attachment:image.png)

# %%
plt.boxplot(high_temp_08)  # box 기준 아래부터 1/4, 2/4, 3/4 지점
plt.show()

# %%
plt.boxplot([high_temp_01, high_temp_08])  # list로 넣으면 여러 boxplot
plt.show()

# %%
# 1~12월까지 저장 list 이용

month_list = [[] for _ in range(12)]  # 지정이 필요한 리스트 생성

for i in range(1, len(datas)):
    month = datas[i][0].split('-')[1]
    if (datas[i][-1] != ''):
        month_list[int(month)-1].append(float(datas[i][-1]))
print(month_list)
# Out:
# [[-1.3, -3.0, -2.9, -1.7, -0.1, 2.9, -1.2, -0.9, 2.0, 3.3, 4.8, 4.5, 4.7, 0.1, 0.9, -4.5, -3.6, 2.8, 2.8, 2.3, -6.1, -5.1, -2.7, 0.1, 0.3, -0.6, 0.0, -1.3, 0.8, 0.8, 6.2, -3.5, 2.5, 5.0, 7.6, 4.7, 1.5, 1.4, -0.1, 0.3, 1.5, 3.3, 1.9, 0.2, 3.0, 2.1, 1.7, 5.5, 5.2, 2.8, 0.2, -2.2, -2.3, 0.7, 4.5, 2.9, 2.2, 0.0, 2.0, 1.5, 1.4, 4.7, 0.6, -4.3, 3.4, 8.0, 7.5, 7.7, 6.8, 5.7, 1.9, 4.5, 7.4, 5.4, 6.9, 6.6, -0.3, -5.2, -6.0, -3.0, -0.1, 4.6, 2.8, 1.3, 0.6, -1.2, -0.6, 2.8, 3.3, 3.2, 0.1, -1.6, -11.0, -6.5, -5.9, -1.4, 2.2, 1.7, -5.6, -3.8, 2.0, 0.7, 5.5, -1.2, -11.6, -9.2, -0.3, -1.3, 0.3, 0.0, 0.5, 1.7, 2.4, 1.1, -1.0, -6.9, -3.0, -1.6, 3.7, 4.7, 7.5, 8.8, 8.2, 7.1, 4.2, -5.4, -2.5, 0.3, 5.1, 4.7, 2.8, 2.5, 2.7, -0.4, -3.3, -3.2, -4.6, -2.2, -4.3, -4.3, -0.5, 1.3, -0.5, 1.2, 0.2, 0.1, 0.6, 3.5, 3.4, 5.4, 4.0, 1.8, -1.5, -0.2, 2.2, -4.2, 1.0, 6.3, -1.3, -7.3, -4.6, -0.6, 3.1, 3.5, -1.3, -2.6, -6.3, -5.1, -4.2, 1.3, 5.1, 2.7, 0.8, -0.6, 3.6, 4.5, 4.6, -0.4, -3.5, -4.0, -2.3, -0.5, 2.4, -0.7, -3
# ...

# %%
# 1~12월까지 저장 dict 이용

month_dict = {}
for i in range(1, 13):
    month_dict[i] = []  # 지정해줄 값이 필요하다는 아이디어
    
for i in range(1, len(datas)):
    month = int(datas[i][0].split('-')[1])
    if datas[i][-1] != '':
        month_dict[month].append(float(datas[i][-1]))
print(month_dict)
# Out:
# {1: [-1.3, -3.0, -2.9, -1.7, -0.1, 2.9, -1.2, -0.9, 2.0, 3.3, 4.8, 4.5, 4.7, 0.1, 0.9, -4.5, -3.6, 2.8, 2.8, 2.3, -6.1, -5.1, -2.7, 0.1, 0.3, -0.6, 0.0, -1.3, 0.8, 0.8, 6.2, -3.5, 2.5, 5.0, 7.6, 4.7, 1.5, 1.4, -0.1, 0.3, 1.5, 3.3, 1.9, 0.2, 3.0, 2.1, 1.7, 5.5, 5.2, 2.8, 0.2, -2.2, -2.3, 0.7, 4.5, 2.9, 2.2, 0.0, 2.0, 1.5, 1.4, 4.7, 0.6, -4.3, 3.4, 8.0, 7.5, 7.7, 6.8, 5.7, 1.9, 4.5, 7.4, 5.4, 6.9, 6.6, -0.3, -5.2, -6.0, -3.0, -0.1, 4.6, 2.8, 1.3, 0.6, -1.2, -0.6, 2.8, 3.3, 3.2, 0.1, -1.6, -11.0, -6.5, -5.9, -1.4, 2.2, 1.7, -5.6, -3.8, 2.0, 0.7, 5.5, -1.2, -11.6, -9.2, -0.3, -1.3, 0.3, 0.0, 0.5, 1.7, 2.4, 1.1, -1.0, -6.9, -3.0, -1.6, 3.7, 4.7, 7.5, 8.8, 8.2, 7.1, 4.2, -5.4, -2.5, 0.3, 5.1, 4.7, 2.8, 2.5, 2.7, -0.4, -3.3, -3.2, -4.6, -2.2, -4.3, -4.3, -0.5, 1.3, -0.5, 1.2, 0.2, 0.1, 0.6, 3.5, 3.4, 5.4, 4.0, 1.8, -1.5, -0.2, 2.2, -4.2, 1.0, 6.3, -1.3, -7.3, -4.6, -0.6, 3.1, 3.5, -1.3, -2.6, -6.3, -5.1, -4.2, 1.3, 5.1, 2.7, 0.8, -0.6, 3.6, 4.5, 4.6, -0.4, -3.5, -4.0, -2.3, -0.5, 2.4, -0.7,
# ...

# %%
data = [month_dict[i] for i in range(1, 13)]
plt.boxplot(data)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

data = r"C:\Users\jjjun_ii\Documents\GitHub\LIKELION_AI\Data_TIL\Data_practice\data\seoul.csv"

with open(data, "r", encoding="cp949") as sel:
    data = csv.reader(sel)
    print(data)
    next(data)

    year = []
    month_list = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

    for mon in month_list:
        tmp_list = []
        sel.seek(0)  # 포인터 되돌리기
        data = csv.reader(sel)  # 다시 데이터 읽기
        next(data)
        for row in data:  # 포인터를 되돌리지 않으면 csv.reader의 포인터가 끝으로 간 후 초기화되지 않아서 데이터를 읽지 못하는 문제 발생
            if row[-1] != "":
                month = row[0].split("-")[1]
                if month == mon:
                    tmp_list.append(float(row[-1]))
        year.append(tmp_list)

plt.boxplot(year)
plt.show()

# %% [markdown]
# ### 4. pandas, plot

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = r"C:\Users\jjjun_ii\Documents\GitHub\LIKELION_AI\Data_TIL\Data_practice\data\seoul.csv"
df = pd.read_csv(data, encoding="cp949")

# %%
df
# Out:
#                날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0      1907-10-01  108     13.5      7.9     20.7
# 1      1907-10-02  108     16.2      7.9     22.0
# 2      1907-10-03  108     16.2     13.1     21.3
# 3      1907-10-04  108     16.5     11.2     22.0
# 4      1907-10-05  108     17.6     10.9     25.4
# ...           ...  ...      ...      ...      ...
# 40216  2019-01-13  108      1.2     -3.0      7.6
# 40217  2019-01-14  108      1.4     -2.4      5.3
# 40218  2019-01-15  108     -1.7     -7.2      2.6
# 40219  2019-01-16  108     -5.2    -10.1     -1.1
# 40220  2019-01-17  108     -0.3     -3.2      4.0
#
# [40221 rows x 5 columns]

# %%
df.dropna(inplace=True)
plt.plot(df["최고기온(℃)"])
# 그래프 중간이 비어있는 이유는 결측값 혹은
# 결측값을 삭제한 후 reset_index로 인덱스 초기화를 하지 않아서

# %%
df.reset_index(inplace=True, drop=True)
df
# Out:
#                날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0      1907-10-01  108     13.5      7.9     20.7
# 1      1907-10-02  108     16.2      7.9     22.0
# 2      1907-10-03  108     16.2     13.1     21.3
# 3      1907-10-04  108     16.5     11.2     22.0
# 4      1907-10-05  108     17.6     10.9     25.4
# ...           ...  ...      ...      ...      ...
# 39458  2019-01-13  108      1.2     -3.0      7.6
# 39459  2019-01-14  108      1.4     -2.4      5.3
# 39460  2019-01-15  108     -1.7     -7.2      2.6
# 39461  2019-01-16  108     -5.2    -10.1     -1.1
# 39462  2019-01-17  108     -0.3     -3.2      4.0
#
# [39463 rows x 5 columns]

# %%
plt.plot(df["최고기온(℃)"])
plt.show()

# %%
data_08 = df[df["날짜"].str.split('-').str[1] == "08"]['최고기온(℃)']  # .str: str 접근
plt.boxplot(data_08, showfliers=False)  # showflier: 이상치 표시
plt.show()

# %% [markdown]
# ### 5. 문자열 찾기

# %%
print("신도림" in "서울특별시 구로구 신도림동(1153051000)")  # 문자열 in으로 찾기
# Out:
# True

# %%
import csv

data = r"C:\Users\jjjun_ii\Documents\GitHub\LIKELION_AI\Data_TIL\Data_practice\data\age.csv"
with open(data, encoding="cp949") as infile:
    reader = csv.reader(infile)
    next(reader)
    datas = []
    for row in reader:
        if "신도림" in row[0]:
            datas.append(row)
datas
# Out:
# [['서울특별시 구로구 신도림동(1153051000)',
#   '37513',
#   '37513',
#   '378',
#   '413',
#   '437',
#   '412',
#   '423',
#   '418',
#   '467',
#   '414',
#   '414',
#   '416',
#   '396',
#   '362',
#   '386',
#   '339',
#   '341',
#   '351',
#   '368',
#   '391',
#   '351',
#   '387',
#   '444',
#   '432',
#   '484',
#   '449',
#   '490',
#   '431',
#   '511',
#   '445',
#   '507',
#   '517',
#   '507',
#   '566',
#   '611',
#   '638',
#   '750',
#   '772',
#   '789',
#   '756',
#   '822',
#   '679',
#   '731',
#   '690',
#   '693',
#   '734',
#   '725',
#   '658',
#   '632',
#   '602',
#   '571',
#   '572',
#   '490',
#   '500',
#   '553',
#   '549',
#   '487',
#   '537',
#   '590',
#   '585',
#   '513',
#   '515',
#   '492',
#   '422',
#   '527',
#   '397',
#   '396',
#   '403',
#   '258',
#   '314',
#   '273',
#   '303',
#   '297',
#   '197',
#   '172',
#   '158',
#   '166',
#   '186',
#   '152',
#   '141',
#   '108',
#   '118',
#   '88',
#   '97',
#   '73',
#   '70',
#   '47',
#   '45',
# ...

# %%
data = r"C:\Users\jjjun_ii\Documents\GitHub\LIKELION_AI\Data_TIL\Data_practice\data\age.csv"
with open(data, encoding="cp949") as infile:
    reader = csv.reader(infile)
    next(reader)
    datas = []
    for row in reader:
        if "신도림" in row[0]:
            for i in row[3:]:
                datas.append(int(i))

plt.style.use('ggplot')  # 그래프 스타일
plt.plot(datas)
plt.show()

# %%
data = r"C:\Users\jjjun_ii\Documents\GitHub\LIKELION_AI\Data_TIL\Data_practice\data\age.csv"

with open(data, encoding="cp949") as infile:
    reader = csv.reader(infile)
    next(reader)
    datas = []
    addr = input("인구 구조를 알고 싶은 지역 이름(읍면동 단위)을 입력해주세요: ")
    
    for row in reader:
        if addr in row[0]:
            for i in row[3:]:
                datas.append(int(i))

plt.style.use("ggplot")
plt.rc("font", family="Malgun Gothic")
plt.title(addr + "의 인구 분포입니다.")
plt.plot(datas)
plt.show()

# %%
data = r"C:\Users\jjjun_ii\Documents\GitHub\LIKELION_AI\Data_TIL\Data_practice\data\gender.csv"

with open(data, encoding="cp949") as infile:
    reader = csv.reader(infile)
    next(reader)
    datas = [[], []]
    for row in reader:
        if "문래동" in row[0]:
            print(row)
# Out:
# ['서울특별시 영등포구 문래동(1156060500)', '15841', '15841', '142', '175', '172', '192', '184', '200', '209', '171', '166', '159', '180', '169', '177', '159', '144', '160', '126', '114', '162', '174', '147', '144', '140', '147', '187', '176', '200', '203', '181', '203', '234', '214', '234', '282', '286', '330', '347', '328', '342', '355', '288', '300', '291', '280', '314', '319', '282', '293', '286', '237', '224', '193', '182', '205', '218', '189', '184', '205', '226', '197', '190', '198', '180', '189', '159', '140', '168', '128', '144', '119', '129', '119', '102', '98', '95', '93', '93', '76', '64', '62', '50', '53', '50', '44', '32', '24', '17', '17', '13', '10', '8', '14', '6', '4', '2', '4', '2', '3', '3', '1', '10', '16204', '16204', '125', '175', '150', '178', '165', '169', '191', '169', '160', '157', '159', '175', '145', '144', '118', '138', '129', '119', '158', '134', '131', '161', '150', '170', '196', '206', '225', '231', '221', '221', '275', '263', '290', '317', '296', '307', '378', '3
# ...

# %%
data = r"C:\Users\jjjun_ii\Documents\GitHub\LIKELION_AI\Data_TIL\Data_practice\data\gender.csv"

with open(data, encoding="cp949") as infile:
    reader = csv.reader(infile)
    next(reader)
    datas = [[], []]
    for row in reader:
        if "문래동" in row[0]:
            for i in range(101):
                datas[0].append(int(row[i+3]))
                datas[1].append(int(row[i+106]))

index = [i for i in range(101)]
plt.plot(index, datas[0], label="남")
plt.plot(index, datas[1], label="여")
plt.legend()
plt.show()

# %%
data = r"C:\Users\jjjun_ii\Documents\GitHub\LIKELION_AI\Data_TIL\Data_practice\data\gender.csv"

with open(data, encoding="cp949") as infile:
    reader = csv.reader(infile)
    next(reader)
    datas = [[], []]
    for row in reader:
        if "문래동" in row[0]:
            for i in range(101):
                datas[0].append(-int(row[i+3]))  # 음수로 붙여서 반대로 출력되게
                datas[1].append(int(row[i+106]))

index = [i for i in range(101)]
plt.rcParams["axes.unicode_minus"] = False  # '-' 기호 깨지는 문제 해결
plt.barh(index, datas[0], label="남")
plt.barh(index, datas[1], label="여")
plt.legend()
plt.show()

# %% [markdown]
# ### 6. pie chart

# %%
import matplotlib.pyplot as plt
plt.pie([10, 20])
plt.show()

# %%
size = [2441, 2312, 1031, 1233]
plt.axis("equal")  # 가로, 세로축 동일한 비율로 유지
plt.pie(size)
plt.show()

# %%
plt.rc("font", family="Malgun Gothic")
size = [2441, 2312, 1031, 1233]
label = ["A형", "B형", "AB형", "O형"]
plt.axis("equal") 
plt.pie(size, labels = label, autopct="%.1f%%")  # autopct: 영역의 백분율 레이블 표시
plt.legend()
plt.show()

# %%
plt.rc("font", family="Malgun Gothic")
size = [2441, 2312, 1031, 1233]
label = ["A형", "B형", "AB형", "O형"]
color = ['darkmagenta', 'deeppink', 'hotpink', 'pink']
plt.axis("equal")
plt.pie(size, labels = label, autopct="%.1f%%", 
        explode=(0,0,0.5,0), colors=color)  # explode: 각 레이블 돌출 정도
plt.legend()
plt.show()

# %%
data = r"C:\Users\jjjun_ii\Documents\GitHub\LIKELION_AI\Data_TIL\Data_practice\data\gender.csv"

with open(data, encoding="cp949") as infile:
    reader = csv.reader(infile)
    header = next(reader)
    print(header)
    datas = []
    addr = input("남여 성비를 구하고 싶은 지역을 입력하세요: ")
    for row in reader:
        if addr in row[0]:
            print(row)
            datas.append(row[1])
            datas.append(row[104])
            break  # 시/도로 표시되는 값에 대해서 처음 값만 그리기 위해
        
print(datas)
plt.axis("equal")
plt.rc("font", family="Malgun Gothic")
plt.pie(datas, labels=["남", "여"], autopct="%.1f%%", startangle=90, colors=["magenta", "orange"] )  # startangle: 수직으로
plt.title(addr + "지역의 남녀 성비입니다.")
plt.legend()
plt.show()
# Out:
# ['행정구역', '2019년01월_남_총인구수', '2019년01월_남_연령구간인구수', '2019년01월_남_0세', '2019년01월_남_1세', '2019년01월_남_2세', '2019년01월_남_3세', '2019년01월_남_4세', '2019년01월_남_5세', '2019년01월_남_6세', '2019년01월_남_7세', '2019년01월_남_8세', '2019년01월_남_9세', '2019년01월_남_10세', '2019년01월_남_11세', '2019년01월_남_12세', '2019년01월_남_13세', '2019년01월_남_14세', '2019년01월_남_15세', '2019년01월_남_16세', '2019년01월_남_17세', '2019년01월_남_18세', '2019년01월_남_19세', '2019년01월_남_20세', '2019년01월_남_21세', '2019년01월_남_22세', '2019년01월_남_23세', '2019년01월_남_24세', '2019년01월_남_25세', '2019년01월_남_26세', '2019년01월_남_27세', '2019년01월_남_28세', '2019년01월_남_29세', '2019년01월_남_30세', '2019년01월_남_31세', '2019년01월_남_32세', '2019년01월_남_33세', '2019년01월_남_34세', '2019년01월_남_35세', '2019년01월_남_36세', '2019년01월_남_37세', '2019년01월_남_38세', '2019년01월_남_39세', '2019년01월_남_40세', '2019년01월_남_41세', '2019년01월_남_42세', '2019년01월_남_43세', '2019년01월_남_44세', '2019년01월_남_45세', '2019년01월_남_46세', '2019년01월_남_47세', '2019년01월_남_48세', '2019년01월_남_49세', '2019년01월_남_50세', '2019년01월_남_51세', '2019년01월_남_52세', '201
# ...

# %% [markdown]
# ### 7. pandas, xlsx

# %%
import pandas as pd

data = r"C:\Users\jjjun_ii\Documents\GitHub\LIKELION_AI\Data_TIL\Visualization\data\dust.xlsx"
dust_df = pd.read_excel(data)
dust_df.head()
# Out:
#               날짜  아황산가스  일산화탄소     오존  이산화질소  PM10  PM2.5
# 0  2021-01-01 01  0.004    0.4  0.021  0.018   NaN   12.0
# 1  2021-01-01 02  0.004    0.4  0.019  0.020  20.0   13.0
# 2  2021-01-01 03  0.004    0.5  0.017  0.023  23.0   13.0
# 3  2021-01-01 04  0.004    0.5  0.015  0.024  17.0   12.0
# 4  2021-01-01 05  0.004    0.5  0.010  0.026   NaN   14.0

# %%
dust_df.shape
# Out:
# (744, 7)

# %%
dust_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      744 non-null    object
#  1   아황산가스   740 non-null    float64
#  2   일산화탄소   740 non-null    float64
#  3   오존      740 non-null    float64
#  4   이산화질소   740 non-null    float64
#  5   PM10    725 non-null    float64
#  6   PM2.5   739 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 40.8+ KB

# %%
dust_df.describe()
# Out:
#             아황산가스       일산화탄소          오존       이산화질소        PM10       PM2.5
# count  740.000000  740.000000  740.000000  740.000000  725.000000  739.000000
# mean     0.003654    0.563243    0.014154    0.030422   33.325517   21.833559
# std      0.000628    0.164593    0.010689    0.014664   19.930029   12.222892
# min      0.002000    0.300000    0.001000    0.006000    3.000000    3.000000
# 25%      0.003000    0.400000    0.003000    0.017000   20.000000   13.000000
# 50%      0.004000    0.500000    0.014000    0.030000   29.000000   19.000000
# 75%      0.004000    0.700000    0.024000    0.043000   43.000000   29.000000
# max      0.006000    1.200000    0.037000    0.063000  163.000000   72.000000

# %%
dust_df.columns = ["date", "so2", "co", "o3", "no2", "PM10", "PM2.5"]
dust_df.head()
# Out:
#             date    so2   co     o3    no2  PM10  PM2.5
# 0  2021-01-01 01  0.004  0.4  0.021  0.018   NaN   12.0
# 1  2021-01-01 02  0.004  0.4  0.019  0.020  20.0   13.0
# 2  2021-01-01 03  0.004  0.5  0.017  0.023  23.0   13.0
# 3  2021-01-01 04  0.004  0.5  0.015  0.024  17.0   12.0
# 4  2021-01-01 05  0.004  0.5  0.010  0.026   NaN   14.0

# %%
dust_df["date"] = dust_df["date"].str[:10]
dust_df.head()
# Out:
#          date    so2   co     o3    no2  PM10  PM2.5
# 0  2021-01-01  0.004  0.4  0.021  0.018   NaN   12.0
# 1  2021-01-01  0.004  0.4  0.019  0.020  20.0   13.0
# 2  2021-01-01  0.004  0.5  0.017  0.023  23.0   13.0
# 3  2021-01-01  0.004  0.5  0.015  0.024  17.0   12.0
# 4  2021-01-01  0.004  0.5  0.010  0.026   NaN   14.0

# %%
dust_df["date"] = pd.to_datetime(dust_df["date"])
dust_df.dtypes
# Out:
# date     datetime64[ns]
# so2             float64
# co              float64
# o3              float64
# no2             float64
# PM10            float64
# PM2.5           float64
# dtype: object

# %%
dust_df["year"] = dust_df["date"].dt.year
dust_df["month"] = dust_df["date"].dt.month
dust_df["day"] = dust_df["date"].dt.day

dust_df.head()
# Out:
#         date    so2   co     o3    no2  PM10  PM2.5  year  month  day
# 0 2021-01-01  0.004  0.4  0.021  0.018   NaN   12.0  2021      1    1
# 1 2021-01-01  0.004  0.4  0.019  0.020  20.0   13.0  2021      1    1
# 2 2021-01-01  0.004  0.5  0.017  0.023  23.0   13.0  2021      1    1
# 3 2021-01-01  0.004  0.5  0.015  0.024  17.0   12.0  2021      1    1
# 4 2021-01-01  0.004  0.5  0.010  0.026   NaN   14.0  2021      1    1

# %%
# 정렬된 dataframe 새로 생성

dust_df_sorted = pd.DataFrame({"date": dust_df["date"], "year": dust_df["year"], 
                          "month": dust_df["month"], "day": dust_df["day"], 
                          "so2": dust_df["so2"], "co": dust_df["co"], 
                          "o3": dust_df["o3"], "no2": dust_df["no2"], 
                          "PM10": dust_df["PM10"], "PM2.5": dust_df["PM2.5"]})
dust_df_sorted.head()
# Out:
#         date  year  month  day    so2   co     o3    no2  PM10  PM2.5
# 0 2021-01-01  2021      1    1  0.004  0.4  0.021  0.018   NaN   12.0
# 1 2021-01-01  2021      1    1  0.004  0.4  0.019  0.020  20.0   13.0
# 2 2021-01-01  2021      1    1  0.004  0.5  0.017  0.023  23.0   13.0
# 3 2021-01-01  2021      1    1  0.004  0.5  0.015  0.024  17.0   12.0
# 4 2021-01-01  2021      1    1  0.004  0.5  0.010  0.026   NaN   14.0

# %%
# 칼럼 순서 바꾸는 간단한 방법

dust_df = dust_df[["date", "year", "month", "day", "so2", "co", "o3", "no2", "PM10", "PM2.5"]]
dust_df.head()
# Out:
#         date  year  month  day    so2   co     o3    no2  PM10  PM2.5
# 0 2021-01-01  2021      1    1  0.004  0.4  0.021  0.018   NaN   12.0
# 1 2021-01-01  2021      1    1  0.004  0.4  0.019  0.020  20.0   13.0
# 2 2021-01-01  2021      1    1  0.004  0.5  0.017  0.023  23.0   13.0
# 3 2021-01-01  2021      1    1  0.004  0.5  0.015  0.024  17.0   12.0
# 4 2021-01-01  2021      1    1  0.004  0.5  0.010  0.026   NaN   14.0

# %%
dust_df.isnull().sum()
# Out:
# date      0
# year      0
# month     0
# day       0
# so2       4
# co        4
# o3        4
# no2       4
# PM10     19
# PM2.5     5
# dtype: int64

# %%
dust_df[dust_df["PM10"].isna()]  # 279, 280, 689, 690은 날짜를 제외하고 모두 NaN
# Out:
#           date  year  month  day    so2   co     o3    no2  PM10  PM2.5
# 0   2021-01-01  2021      1    1  0.004  0.4  0.021  0.018   NaN   12.0
# 4   2021-01-01  2021      1    1  0.004  0.5  0.010  0.026   NaN   14.0
# 140 2021-01-06  2021      1    6  0.003  0.6  0.008  0.035   NaN   13.0
# 260 2021-01-11  2021      1   11  0.004  0.7  0.001  0.049   NaN   31.0
# 270 2021-01-12  2021      1   12  0.004  0.7  0.002  0.040   NaN   44.0
# 279 2021-01-12  2021      1   12    NaN  NaN    NaN    NaN   NaN    NaN
# 280 2021-01-12  2021      1   12    NaN  NaN    NaN    NaN   NaN    NaN
# 281 2021-01-12  2021      1   12  0.003  0.9  0.001  0.052   NaN    NaN
# 284 2021-01-12  2021      1   12  0.004  1.0  0.001  0.056   NaN   56.0
# 386 2021-01-17  2021      1   17  0.004  0.4  0.027  0.010   NaN   16.0
# 391 2021-01-17  2021      1   17  0.004  0.5  0.020  0.018   NaN   11.0
# 508 2021-01-22  2021      1   22  0.003  0.7  0.001  0.040   NaN   28.0
# ...

# %%
# 시계열 분석이므로 null 값을 이전 시간의 값을 기준으로 채워줌
# 결측값을 앞 방향 혹은 뒷 방향으로 채우기

dust_df = dust_df.fillna(method="pad")  # method = pad: 이전 행의 값으로 대체
dust_df.isnull().sum()  # 채워지지 않은 데이터는 이전 값이 없기 떄문에 => 0행
# Out:
# date     0
# year     0
# month    0
# day      0
# so2      0
# co       0
# o3       0
# no2      0
# PM10     1
# PM2.5    0
# dtype: int64

# %%
dust_df.fillna(20,inplace=True)  # 첫 행 채우기
dust_df.head()
# Out:
#         date  year  month  day    so2   co     o3    no2  PM10  PM2.5
# 0 2021-01-01  2021      1    1  0.004  0.4  0.021  0.018  20.0   12.0
# 1 2021-01-01  2021      1    1  0.004  0.4  0.019  0.020  20.0   13.0
# 2 2021-01-01  2021      1    1  0.004  0.5  0.017  0.023  23.0   13.0
# 3 2021-01-01  2021      1    1  0.004  0.5  0.015  0.024  17.0   12.0
# 4 2021-01-01  2021      1    1  0.004  0.5  0.010  0.026  17.0   14.0

# %%
dust_df[dust_df["PM10"].isnull()]
# Out:
# Empty DataFrame
# Columns: [date, year, month, day, so2, co, o3, no2, PM10, PM2.5]
# Index: []

# %%
import pandas as pd

data = r"C:\Users\jjjun_ii\Documents\GitHub\LIKELION_AI\Data_TIL\Visualization\data\weather.xlsx"

weather_df = pd.read_excel(data)
weather_df.head()
# Out:
#     지점 지점명                  일시  기온(°C)  풍속(m/s)  강수량(mm)  습도(%)
# 0  400  강남 2021-01-01 01:00:00    -7.2      0.6      0.0   57.5
# 1  400  강남 2021-01-01 02:00:00    -7.6      0.7      0.0   57.5
# 2  400  강남 2021-01-01 03:00:00    -8.2      0.6      0.0   62.0
# 3  400  강남 2021-01-01 04:00:00    -8.1      0.5      0.0   60.5
# 4  400  강남 2021-01-01 05:00:00    -8.7      1.3      0.0   66.4

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 743 entries, 0 to 742
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지점       743 non-null    int64
#  1   지점명      743 non-null    object
#  2   일시       743 non-null    datetime64[ns]
#  3   기온(°C)   743 non-null    float64
#  4   풍속(m/s)  743 non-null    float64
#  5   강수량(mm)  743 non-null    float64
#  6   습도(%)    743 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 40.8+ KB

# %%
weather_df.describe()
# Out:
#           지점                   일시      기온(°C)     풍속(m/s)     강수량(mm)  \
# count  743.0                  743  743.000000  743.000000  743.000000
# mean   400.0  2021-01-16 12:00:00   -1.937281    1.283715    0.033647
# min    400.0  2021-01-01 01:00:00  -16.900000    0.000000    0.000000
# 25%    400.0  2021-01-08 18:30:00   -6.600000    0.600000    0.000000
# 50%    400.0  2021-01-16 12:00:00   -2.200000    1.100000    0.000000
# 75%    400.0  2021-01-24 05:30:00    3.100000    1.800000    0.000000
# max    400.0  2021-01-31 23:00:00   14.600000    5.200000    2.500000
# std      0.0                  NaN    6.523592    0.944535    0.219221
#
#             습도(%)
# count  743.000000
# mean    57.256393
# min     16.400000
# 25%     40.350000
# 50%     52.800000
# 75%     73.650000
# max     99.900000
# std     21.849992

# %%
weather_df.drop(["지점", "지점명"], axis=1, inplace=True)
weather_df.head()
# Out:
#                    일시  기온(°C)  풍속(m/s)  강수량(mm)  습도(%)
# 0 2021-01-01 01:00:00    -7.2      0.6      0.0   57.5
# 1 2021-01-01 02:00:00    -7.6      0.7      0.0   57.5
# 2 2021-01-01 03:00:00    -8.2      0.6      0.0   62.0
# 3 2021-01-01 04:00:00    -8.1      0.5      0.0   60.5
# 4 2021-01-01 05:00:00    -8.7      1.3      0.0   66.4

# %%
weather_df.columns = ["date", "temp", "wind", "rain", "humid"]
weather_df.head()
# Out:
#                  date  temp  wind  rain  humid
# 0 2021-01-01 01:00:00  -7.2   0.6   0.0   57.5
# 1 2021-01-01 02:00:00  -7.6   0.7   0.0   57.5
# 2 2021-01-01 03:00:00  -8.2   0.6   0.0   62.0
# 3 2021-01-01 04:00:00  -8.1   0.5   0.0   60.5
# 4 2021-01-01 05:00:00  -8.7   1.3   0.0   66.4

# %%
weather_df["date"] = weather_df["date"].dt.date  # datetime64[ns] => object 형식으로 바뀜
print(weather_df.dtypes)  
weather_df.head()
# Out:
# date      object
# temp     float64
# wind     float64
# rain     float64
# humid    float64
# dtype: object
#          date  temp  wind  rain  humid
# 0  2021-01-01  -7.2   0.6   0.0   57.5
# 1  2021-01-01  -7.6   0.7   0.0   57.5
# 2  2021-01-01  -8.2   0.6   0.0   62.0
# 3  2021-01-01  -8.1   0.5   0.0   60.5
# 4  2021-01-01  -8.7   1.3   0.0   66.4

# %%
weather_df["date"] = pd.to_datetime(weather_df["date"])
print(weather_df.dtypes)
weather_df.head()
# Out:
# date     datetime64[ns]
# temp            float64
# wind            float64
# rain            float64
# humid           float64
# dtype: object
#         date  temp  wind  rain  humid
# 0 2021-01-01  -7.2   0.6   0.0   57.5
# 1 2021-01-01  -7.6   0.7   0.0   57.5
# 2 2021-01-01  -8.2   0.6   0.0   62.0
# 3 2021-01-01  -8.1   0.5   0.0   60.5
# 4 2021-01-01  -8.7   1.3   0.0   66.4

# %%
weather_df.isnull().sum()
# Out:
# date     0
# temp     0
# wind     0
# rain     0
# humid    0
# dtype: int64

# %%
# 열 값 변경

weather_df["rain"] = weather_df[weather_df["rain"] == 0.01]["rain"] = 1  # 슬라이싱 하면 얕은 복사니까
weather_df.head()
# Out:
#         date  temp  wind  rain  humid
# 0 2021-01-01  -7.2   0.6     1   57.5
# 1 2021-01-01  -7.6   0.7     1   57.5
# 2 2021-01-01  -8.2   0.6     1   62.0
# 3 2021-01-01  -8.1   0.5     1   60.5
# 4 2021-01-01  -8.7   1.3     1   66.4

# %%
weather_df.loc[weather_df["rain"] == 1, ["rain"]] = 0.1
weather_df.head()
# Out:
#         date  temp  wind  rain  humid
# 0 2021-01-01  -7.2   0.6   0.1   57.5
# 1 2021-01-01  -7.6   0.7   0.1   57.5
# 2 2021-01-01  -8.2   0.6   0.1   62.0
# 3 2021-01-01  -8.1   0.5   0.1   60.5
# 4 2021-01-01  -8.7   1.3   0.1   66.4

# %%
weather_df["rain"] = weather_df["rain"].apply(lambda x: 0.01 if x == 0.1 else x)  # else 뒤 원래 값이면 변수 그대로
weather_df.head()
# Out:
#         date  temp  wind  rain  humid
# 0 2021-01-01  -7.2   0.6  0.01   57.5
# 1 2021-01-01  -7.6   0.7  0.01   57.5
# 2 2021-01-01  -8.2   0.6  0.01   62.0
# 3 2021-01-01  -8.1   0.5  0.01   60.5
# 4 2021-01-01  -8.7   1.3  0.01   66.4

# %% [markdown]
# ##### 1-9. merge

# %%
weather_df.shape
# Out:
# (743, 5)

# %%
dust_df.shape
# Out:
# (744, 10)

# %%
dust_df.drop(index=743, inplace=True)
dust_df.shape
# Out:
# (743, 10)

# %%
df_merge = pd.concat([weather_df, dust_df], axis=1)
df_merge.head()
# Out:
#         date  temp  wind  rain  humid       date  year  month  day    so2  \
# 0 2021-01-01  -7.2   0.6  0.01   57.5 2021-01-01  2021      1    1  0.004
# 1 2021-01-01  -7.6   0.7  0.01   57.5 2021-01-01  2021      1    1  0.004
# 2 2021-01-01  -8.2   0.6  0.01   62.0 2021-01-01  2021      1    1  0.004
# 3 2021-01-01  -8.1   0.5  0.01   60.5 2021-01-01  2021      1    1  0.004
# 4 2021-01-01  -8.7   1.3  0.01   66.4 2021-01-01  2021      1    1  0.004
#
#     co     o3    no2  PM10  PM2.5
# 0  0.4  0.021  0.018  20.0   12.0
# 1  0.4  0.019  0.020  20.0   13.0
# 2  0.5  0.017  0.023  23.0   13.0
# 3  0.5  0.015  0.024  17.0   12.0
# 4  0.5  0.010  0.026  17.0   14.0

# %%
df_merge.shape
# Out:
# (17808, 14)

# %%
df_merge = pd.merge(weather_df, dust_df, on="date")
df_merge.head()
# Out:
#         date  temp  wind  rain  humid  year  month  day    so2   co     o3  \
# 0 2021-01-01  -7.2   0.6  0.01   57.5  2021      1    1  0.004  0.4  0.021
# 1 2021-01-01  -7.2   0.6  0.01   57.5  2021      1    1  0.004  0.4  0.019
# 2 2021-01-01  -7.2   0.6  0.01   57.5  2021      1    1  0.004  0.5  0.017
# 3 2021-01-01  -7.2   0.6  0.01   57.5  2021      1    1  0.004  0.5  0.015
# 4 2021-01-01  -7.2   0.6  0.01   57.5  2021      1    1  0.004  0.5  0.010
#
#      no2  PM10  PM2.5
# 0  0.018  20.0   12.0
# 1  0.020  20.0   13.0
# 2  0.023  23.0   13.0
# 3  0.024  17.0   12.0
# 4  0.026  17.0   14.0

# %%
df_merge.shape
# Out:
# (17808, 14)

# %% [markdown]
# ### 9. corr

# %%
df_merge.corr()
# Out:
#            date      temp      wind  rain     humid  year  month       day  \
# date   1.000000  0.491312 -0.074944   NaN  0.176721   NaN    NaN  1.000000
# temp   0.491312  1.000000 -0.211112   NaN  0.213428   NaN    NaN  0.491312
# wind  -0.074944 -0.211112  1.000000   NaN -0.461900   NaN    NaN -0.074944
# rain        NaN       NaN       NaN   NaN       NaN   NaN    NaN       NaN
# humid  0.176721  0.213428 -0.461900   NaN  1.000000   NaN    NaN  0.176721
# year        NaN       NaN       NaN   NaN       NaN   NaN    NaN       NaN
# month       NaN       NaN       NaN   NaN       NaN   NaN    NaN       NaN
# day    1.000000  0.491312 -0.074944   NaN  0.176721   NaN    NaN  1.000000
# so2   -0.318239 -0.375131  0.031460   NaN -0.096445   NaN    NaN -0.318239
# co     0.226099  0.318052 -0.322431   NaN  0.338083   NaN    NaN  0.226099
# o3    -0.118081 -0.203804  0.355105   NaN -0.288327   NaN    NaN -0.118081
# ...

# %%
df_merge.corr()["PM10"].sort_values(ascending=False)
# Out:
# PM10     1.000000
# PM2.5    0.825433
# co       0.529720
# no2      0.420554
# humid    0.216753
# temp     0.175430
# so2      0.160874
# date     0.016124
# day      0.016124
# wind    -0.108474
# o3      -0.348229
# rain          NaN
# year          NaN
# month         NaN
# Name: PM10, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.hist(df_merge)  # 모든 데이터가 하나의 그래프에
plt.show()

# %%
df_merge.hist(figsize=(20,12))  # df.hist: 각 열마다 따로 그래프
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 10))
day_graph = sns.barplot(x="day", y="PM10", data=df_merge)
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(20, 12))
sns.heatmap(df_merge.corr(), annot=True, fmt='.2f', cmap="hot")
# Out:
# <Axes: >

# %%
temp = df_merge["temp"]
PM10 = df_merge["PM10"]

plt.figure(figsize=(10, 6))
plt.scatter(temp, PM10)
plt.show()

# %%
PM = df_merge["PM2.5"]
PM10 = df_merge["PM10"]

plt.figure(figsize=(10, 6))
plt.scatter(PM10, PM)
plt.show()
