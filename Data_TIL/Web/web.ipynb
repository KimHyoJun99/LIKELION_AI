# %% [markdown]
# # Web

# %% [markdown]
# ### 1. basic web crawling
# - Crawling: 웹상에 공개된 내용에서 데이터를 추출하는 것
# - Crawler: 웹 크롤링을 하는 프로그램
# - HTML: HyperText Markup Language, 웹 페이지를 만들기 위한 대표적인 마크업 언어
# - HTML 문법 중 <> 안에 들어 있는 구문을 태그(Tag)라고 부름

# %% [markdown]
# ##### 1-1. HTML 구조

# %% [markdown]
# ```HTML
# <html>
# <head>
#     화면에 표시되지 않는 정보(타이틀, 인코딩 정보 등을 표현)
# </head>
#
# <body>
#     화면에 표시되는 본체(주로 태그를 표현)
# </body>
# </html>
#
# - <html>~</html>:
# 전체 코드를 감쌈
# - <head>~</head>:
# 타이틀, 인코딩 정보 등 화면에 표시되지 않는 정보를  포함
# - <body>~</body>:
# 주로 화면에 표시되는 본체 및 태그를 포함, 필요하다면 태그에 속성을 표시할 수 있음
# - <title>~</title>:
# 주로 <head> 속에서 웹 브라우저의 타이틀 바에 표시되는 웹 페이지의 제목을 표시
# ```

# %% [markdown]
# ##### 1-2. HTML 태그

# %% [markdown]
# ```HTML
# - <meta>
# 웹 페이지의 정보를 설정
# 검색 엔진에서 문서의 내용을 요약해 주기도 하며, 언어의 설정에도 사용
# <head> 영역에 표현하며 웹 페이지의 문자 코딩을 UTF-8로 인식되게 함
#
# - <br>
# 행을 바꿔 줌
#
# - <u>~</u>, <b>~</b>, <i>~</i>
# 밑줄, 볼드체, 이탤릭체를 지정
#
# - <font>~</font>
# 글자의 크기나 색상을 지정
#
# - <hr>
# 수평선을 그어줌
# <hr size='픽셀수'>는 픽셀수의 폭으로 선을 그어줌
#
# - <a>~</a>
# 클릭하면 다른 페이지가 연결되는 링크를 설정
# 주로 href 속성으로 연결된 홈페이지를 지정
# target 속성을 지정하지 않으면 현재 페이지에서 열림
#
# - <img>
# 이미지 파일을 화면에 표시
# width와 height를 생략하면 그림의 원본 크기로 출력됨
#
# - <table>~</table>, <tr>~</tr>, <th>~</th>, <td>~</td>
# 표를 만드는 태그들
# <table>~</table> 태그 안에 행은 <tr>~</tr>로 구성되고, 행 안에 열이 <th>~</th> 또는 <td>~</td>로 구성
# <th>는 제목 열을 표현해서 볼드체로 보이며 <td>는 일반 열로 표현됨
#
# - <div>~</div>
# Division의 약자이며, 웹 페이지에서 레이아웃을 만들 때 사용
# 필요한 부분을 묶어주는 역할을 하고, style을 지정해서 해당 부분을 표현할 수 있음
#
# -<ul>~</ul>, <li>~</li>
# <ul>은 Unordered List의 약자로 순서가 필요 없는 목록을 만들 때 사용함
# <li>는 List의 약자로 실제 목록을 만듦
# 대부분 <ul>로 바깥을 묶어준 후에, <li>로 세부적인 항목을 표현함
# 주로 id 및 class와 함께 사용됨
#
# - <strong>~</strong>, <em>~</em>
# 글자를 강조할 때 사용
#
# - <p>~</p>
# Paragraph의 약자로, 하나의 문단을 만들 때 쓰임
#
# - <span>~</span>
# <div>와 용도가 비슷함
# <span>은 한 줄 단위를 지정할 때 주로 사용하고, <div>는 블록 단위를 지정할 때 주로 사용함
#
# - id 속성과 class 속성
# id 속성은 HTML 문서 중에서 유일한 값으로 하나의 태그에만 지정할 수 있음
# class 속성은 여러 개의 태그에 지정할 수 있음
# <div id = "myid">
#     div에 id를 설정했어요.
# </div>
# <div class = "myclass">
#     div에 class를 설정했어요.
# </div>
# <div class = "myclass">
#     div에 class를 중복 설정했어요.
# </div>
# ```

# %% [markdown]
# ##### 1-3. 라이브러리 활용

# %%
from bs4 import BeautifulSoup
import urllib.request

nateUrl = "https://www.nate.com"
htmlObject = urllib.request.urlopen(nateUrl)
bsObject = BeautifulSoup(htmlObject, 'html.parser')

print(bsObject)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="//www.nate.com/" name="msapplication-starturl"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="" name="nate:title"/>
# <meta content="네이트 이슈UP" name="nate:description"/>
# <meta content="네이트 홈" name="nate:site_name"/>
# <meta content="https://www.nate.com/" name="nate:url"/>
# <meta content="" name="nate:image"/>
# <meta content="새로워진 nate에서 당신의 오늘을 만나보세요" name="description"/>
# <meta content="한눈에 보는 오늘 : 네이트" property="og:title"/>
# <meta content="https://www.nate.com/" property="og:url"/>
# <meta content="https://main.nateimg.co.kr/img/v7/OpenGraphTag_nate_240x240.png" property="og:image"/>
# <meta content="새로워진 nate에서 당신의 오늘을 만나보세요" property="og:description"/>
# <title>한눈에 보는 오늘 : 네이트</title>
# <link href="/css/common.min.css?v=202309201110_01" rel="stylesheet" type="text/css"/>
# <link href="//main.nateimg.co.kr/img/v7/favicon_32.ico" rel="shortcut icon" type="image/x-icon">
# <link href="//www.nate.com" rel="canonical"/>
# <script src="/js/common/jquery-1.9.1.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	var isSvc = true; var isInfoAjax = true;
# 	var make = 't';
# 	var isMakeLogin = '';
# 	var host = 'www.nate.com';
# 	var isNateLogin = (isMakeLogin == "Y") ? true : false;
# 	var myId = "";
# 	var iSvcSeq  ='1';
# 	var iSvcSeqB ='1';
# 	var iSvcSeqC ='1';
# 	var currentWeatherIndex = [0,11,8];
# 	var iSvcSeqW = iSvcSeqB;
# 	var isCommsbarOpen = ('N' == 'Y') ? true : false;
# 	var loginType = '';
# 	var isiPad = (navigator.userAgent.toUpperCase().indexOf("IPAD") !== -1);
# 	var isGalaxyTab = (navigator.userAgent.toUpperCase().indexOf("SHW-M180") !== -1); // GT-P1000
# 	var isGalaxyTab10 = (navigator.userAgent.toUpperCase().indexOf("SHW-M380") !== -1);
# 	var isTablet = (isiPad == true || isGalaxyTab == true || isGalaxyTab10 == true);
# 	if (isTablet)
# 	{
# 	    document.write('<link rel="apple-touch-icon-precomposed" href="//main.nateimg.co.kr/img/nate_144.png" />');
# 	}
# 	var loginBoxName 	= "아이디 or @이하 모두 입력";
# 	var hostInfo 	 	= (host.length > 0) ? '//' + host : '';
#
# 	var verIssue01 		= '202310161002';
# 	var verIssue02 		= '202310161002';
# 	var verIssue03 		= '202310161002';
# 	var verIssue04 		= '202310161002';
# 	var verIssue05 		= '202310161002';
# 	var verIssue06 		= '202310161002';
# 	var verIssue07 		= '202310161002';
#
# 	var verNateTV		= '202310161003';
# 	var verIssueKeyword	= '202310161000';
# 	var verToonNBook	= '202310160947';
#
# 	var verNateQ01		= '202310160958';
# 	var verRanking06	= '202310161004';
#
# 	var verGnbRoll		= '202310161002';
# 	var verNewsBox 		= '202310161004';
# 	var verShopRecomm	= '202310160911';
# 	var verNateQ02		= '202310160905';
#
# 	var verPannTotal		= '202310161003';
# 	var verPannWomanLife	= '202310161004';
# 	var verPannTeens		= '202310161004';
# 	var verPannEnter		= '202310161003';
# 	var verTodayKeyword 	= '202310161003';
# 	var verWorkLife			= '202310160954';
# 	var verKeywordAd		= '202310160918';
# 	var verAdFunFun			= '202310160936';
# 	var verBizSearch 		= '202310061709';
# 	var verPann01 			= '201907240835';
# 	var verPann02 			= '201907240835';
#
# 	var shoppingInspection 		= 'N';
# 	var isEmergencyShoppingTab 	= 'N';
# 	var isAutoRefresh 			= true;
# 	var isChangeTab 			= false;
# 	var nateAwardsStat			= '';
# 	var isViewKeywordRank		= 'N';
# 	var isEmergencyToonNBookTab = 'N';
#
# 	//]]>
# 	</script>
# <script src="/js/common/nate_general_v20170627.js?v=202309201110_15" type="text/javascript"></script>
# <script src="/js/common/ac_v5.js?v=20221017_07" type="text/javascript"></script>
# <script src="/js/common/nate_logout_v20170627.js?v=202001141024_01" type="text/javascript"></script>
# <script type="text/javascript">
# 		 //<![CDATA[
# 			var bLogout = false;
# 	    	if (isLogout()) { fillLogout(); }
# 		 //]]>
# 		</script>
# </link></head>
# <body>
# <script type="text/javascript">
# 	 //<![CDATA[
# 		pageEnd2('st');
# 	 //]]>
# 	</script>
# <div id="mainContainer">
# <div class="area_access">
# <h2>네이트 메인페이지 주요 내용 바로가기</h2>
# <ul>
# <li><a href="#search"><strong>통합검색 바로가기</strong></a></li>
# <li><a href="#UI"><strong>로그인영역 바로가기</strong></a></li>
# <li><a href="#news_area"><strong>본문영역 바로가기</strong></a></li>
# </ul>
# </div>
# <div id="container">
# <div id="header">
# <div class="area_bi" id="NateBi" role="banner">
# <h1 class="bi" title="네이트"><a href="//www.nate.com/?f=bi" onmousedown="nc('NBI01');">네이트</a></h1>
# </div>
# <div class="area_ignb" id="divignb">
# <h2>독립GNB</h2>
# <h3>편리한 네이트</h3>
# <ul>
# <li><a href="https://search.daum.net/nate?thr=sbma&amp;w=tot&amp;q=%EB%84%A4%EC%9D%B4%ED%8A%B8%EC%95%B1" onmousedown="nc('NBI04');">네이트앱</a></li>
# <li><a href="//nateonweb.nate.com/" onmousedown="nc('NBI05');">네이트온</a></li>
# <li><a href="http://www.cymera.com/main/ko" onmousedown="nc('NBI07');">싸이메라</a></li>
# </ul>
# </div>
# <div class="area_search" role="search">
# <h2>통합검색</h2>
# <form accept-charset="utf-8" action="https://search.daum.net/nate" id="search" name="search" onsubmit="return checkSearchForm()">
# <input id="thr" name="thr" type="hidden" value="sbma"/>
# <input id="w" name="w" type="hidden" value="tot"/>
# <fieldset>
# <legend>통합검색 입력</legend>
# <div class="home" id="acWrap" onmouseover="ac_LoadByNateMain();">
# <input autocomplete="off" class="type_text" id="q" name="q" onkeydown="return checkSearchQEnter(event)" onmousedown="clickSearchKeywordAd()" style="ime-mode:active" type="text" value=""/>
# <input class="type_btn" id="acBtn" title="검색" type="submit"/>
# <div id="acDiv" style="display:none;"></div>
# </div>
# </fieldset>
# </form>
# <input id="premiumText" name="premiumText" title="" type="hidden" value="">
# <input id="premiumLink" name="premiumLink" title="" type="hidden" value=""/>
# <input id="statCode" name="statCode" title="" type="hidden" value=""/>
# <div class="search_keyword">
# <dl>
# <dd>
# <a href="https://search.daum.net/nate?w=tot&amp;q=%EC%86%90%ED%97%8C%EC%88%98+%EA%B2%B0%ED%98%BC&amp;rtmaxcoll=NNS" id="onclick_semantic01" onmousedown="setNcCode('NSC11|NSC21|NSC31',iSvcSeq-1);">손헌수 결혼</a>
# <a href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=%EC%82%AC%EB%AC%B4%EC%9A%A9%EC%9D%98%EC%9E%90" id="onclick_semantic02" onmousedown="setNcCode('NSC12|NSC22|NSC32',iSvcSeq-1);">사무실의자</a>
# <a href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=%EC%A0%95%EB%A7%A5%EB%A5%98" id="onclick_semantic03" onmousedown="setNcCode('NSC13|NSC23|NSC33',iSvcSeq-1);">정맥류 수술비</a>
# <a href="https://search.daum.net/nate?w=tot&amp;q=%ED%80%B8%EC%A6%88%EC%95%84%EC%9D%B4+THIS+IS+LOVE&amp;rtmaxcoll=NNS" id="onclick_semantic04" onmousedown="setNcCode('NSC14|NSC24|NSC34',iSvcSeq-1);">퀸즈아이 컴백</a>
# <a href="https://search.daum.net/nate?w=tot&amp;q=%EB%8D%94+%EB%A7%88%EB%B8%94%EC%8A%A4+%EC%8A%A4%ED%8B%B8&amp;rtmaxcoll=NNS" id="onclick_semantic05" onmousedown="setNcCode('NSC15|NSC25|NSC35',iSvcSeq-1);">더 마블스 스틸</a>
# </dd>
# </dl>
# </div>
# <a class="link-ngpt" href="https://m.nate.com/aichat.html" onmousedown="nc('NNC01');" target="_blank">AI챗 바로가기</a>
# </input></div>
# <div class="area_gnb" id="divGnb" role="navigation">
# <h2>GNB</h2>
# <ul>
# <li class="mail"><a href="https://mail3.nate.com/#index" onmousedown="nc('NGB01');">메일</a></li>
# <li class="news"><a href="//news.nate.com/" onmousedown="nc('NEV31');">뉴스</a></li>
# <li class="pann"><a href="https://pann.nate.com/" onmousedown="nc('NGB02');">판</a></li>
# <li class="chat1"><a href="https://m.nate.com/aichat.html" onmousedown="nc('NGB51');" target="_blank">AI챗</a><em class="beta">beta</em></li>
# <li class="tv"><a href="https://tv.nate.com/" onmousedown="nc('NGB43');">TV</a></li>
# <li class="comics"><a href="https://toonnbook.nate.com/" onmousedown="nc('NGB44');">툰앤북</a></li>
# <li class="fortune"><a href="https://fortune.nate.com/home/main.nate" onmousedown="nc('NGB05');">운세</a></li>
# <li class="game"><a href="http://game.nate.com/" onmousedown="nc('NGB06');">게임</a></li>
# <li class="shopping"><a href="//shopping.nate.com/" onmousedown="nc('NGB17');">쇼핑</a></li>
# <li class="car"><a href="https://auto.nate.com/" onmousedown="nc('NGB03');">자동차</a></li>
# <li class="teamroom"><a href="https://nateonweb.nate.com/teamroom/" onmousedown="nc('NGB42');" title="함께하는 일이 쉬워진다">팀룸</a></li>
# <li class=""><a href="https://view.nate.com/" onmousedown="nc('NGB50');" title="네이트뷰">네이트뷰</a></li>
# <li class="more">
# <a href="javascript:;" id="aGnbMore" onmousedown="nc('NGB31');" title="전체 서비스 더보기">더보기</a>
# <div class="list_svc" style="display:none">
# <ul class="row_first">
# <li><a href="//news.nate.com" onmousedown="nc('NSD30');"><strong>뉴스</strong></a></li>
# <li><a href="//news.nate.com/Weather" onmousedown="nc('NSD45');">날씨</a></li>
# <li><a href="//sports.news.nate.com/" onmousedown="nc('NSD74');">스포츠</a></li>
# <li><a href="//news.nate.com/ent/index" onmousedown="nc('NSD75');">연예</a></li>
# <li><a href="//news.nate.com/ent/idol24" onmousedown="nc('NSD02');">아이돌24</a></li>
# <li><a href="//news.nate.com/rank/interest" onmousedown="nc('NSD01');">랭킹뉴스</a></li>
# </ul>
# <ul class="row_second">
# <li><a href="https://pann.nate.com/" onmousedown="nc('NSD68');"><strong>판</strong></a></li>
# <li><a href="https://pann.nate.com/talk" onmousedown="nc('NSD06');">톡톡</a></li>
# <li><a href="https://pann.nate.com/talk/imageTheme/index" onmousedown="nc('NSD08');">판포토</a></li>
# <li><a href="https://pann.nate.com/fantalk" onmousedown="nc('NSD76');">팬톡</a></li>
# </ul>
# <ul class="row_third">
# <li><a href="//nateonweb.nate.com/" onmousedown="nc('NSD37');">네이트온</a></li>
# <li><a href="//cash.nate.com/center/cashMain.sc" onmousedown="nc('NSD38');">네이트캐쉬</a></li>
# <li><a href="https://sms.nate.com/" onmousedown="nc('NSD35');">문자메시지</a></li>
# <li><a href="https://mail.nate.com/pims/" onmousedown="nc('NSD34');">주소록</a></li>
# </ul>
# <ul class="row_fourth">
# <li><a href="//mobile.nate.com/" onmousedown="nc('NSD41');">컬러링</a></li>
# <li><a href="//editor.nate.com/" onmousedown="nc('NSD42');">이슈UP추천</a></li>
# </ul>
# <span><a href="https://www.nate.com/sitemap/index.html" onmousedown="nc('NSD91');">서비스 전체보기</a></span>
# <button onmousedown="nc('NSD95');" title="더보기 닫기" type="button" value="더보기 닫기">더보기 닫기</button>
# </div>
# </li>
# </ul>
# </div>
# <div class="area_rtkwd type_alone" id="keywordRank">
# <h3 class="nHide"><a href="#" title="네이트 인기검색어로 이동">실시간 검색어</a></h3>
# </div>
# <div class="area_biz type_alone" id="bizRank">
# <h3 class="nHide"><a href="#" title="네이트 인기검색어로 이동">비즈 검색어</a></h3>
# </div>
# <div class="todayBox" id="divTodayKeywordArea" onmouseout="todayKeyword.startTodayKeyword()" onmouseover="todayKeyword.stopTodayKeyword()">
# <div id="divTodayKeyword">
# <a class="keyword" href="https://news.nate.com/?keyword_dtm=2023-10-16 09:45:47&amp;keyword_sq=182522" onmousedown="nc('TOD51');" title="이재명 위증교사 혐의 추가 기소">이재명 위증교사 혐의 추가 기소</a>
# </div>
# <div class="kwrd_slide">
# <div class="today_tit">
# <a href="https://news.nate.com/" onmousedown="nc('TOD61');">
# <div class="logoimg">
# <div class="circle step1"></div>
# <div class="circle step2"></div>
# </div>
# <span class="svcname">오늘</span>
# </a>
# </div>
# <button class="btn prev" id="Prev" onclick="todayKeyword.viewPreNext('P')" onmousedown="nc('TOD91');" title="이전" type="button"><span>오늘 키워드 이전 내용</span></button>
# <button class="btn next" id="Next" onclick="todayKeyword.viewPreNext('N')" onmousedown="nc('TOD92');" title="다음" type="button"><span>오늘 키워드 다음 내용</span></button>
# </div>
# </div>
# </div>
# <hr/>
# <div id="content">
# <div class="area_auth" id="UI">
# <h2>회원 로그인 영역</h2>
# <script type="text/javascript">
#                     //<![CDATA[
#                         document.write('<script type="text/javascript" src="/common/secure/js/combine/combine_xecure_nate-secure_common.js?v=2022111801"><\/script>');
#                     //]]>
#                     </script>
# <form action="https://xo.nate.com/LoginAuth.sk" id="f_login" method="post" name="f_login" onsubmit="return SubmitCheck();" target="_top">
# <input id="redirect" name="redirect" type="hidden" value="https://www.nate.com/"/>
# <input id="PASSWD_RSA" name="PASSWD_RSA" type="hidden" value=""/>
# <input id="domain" name="domain" type="hidden" value="nate.com"/>
# <input name="cpurl" type="hidden" value="www_ndr.nate.com%2Flogin%2F"/>
# <fieldset>
# <legend>회원 로그인</legend>
# <label class="label_id nHide" for="ID">아이디 or @이하 모두 입력</label>
# <input class="input_id" id="ID" name="ID" style="ime-mode:disabled;" title="아이디 or @이하 모두 입력" type="text" value=""/>
# <label class="label_pw nHide" for="PASSDM">비밀번호</label>
# <label class="label_pw nHide" for="PASSDM" id="lb_passdm">비밀번호</label>
# <input class="input_pw" id="PASSDM" maxlength="20" name="PASSDM" readonly="readonly" type="text" value="비밀번호"/>
# <label class="label_pw nHide" for="PASSWD" id="lb_passwd">비밀번호</label>
# <input class="input_pw" enc="on" id="PASSWD" maxlength="20" name="PASSWD" onblur="vBlurPassInput();" style="display:none;ime-mode:disabled;" type="password"/>
# <span class="option01"><input class="chk_saveid" id="keeplogin" name="keeplogin" onclick="isKeepLogin('on')" onmousedown="nc('NCM94');" type="checkbox"/> <label class="set_saveid" for="keeplogin" onmousedown="nc('NCM94');">로그인 유지</label> <i class="bar">|</i> <a class="ip" href="javascript:xXecurePop.openWin(3);" onmousedown="nc('NLI15');" title="새창 열림">IP보안 <strong id="ipLevelText">ON</strong></a></span>
# <input class="icon_login" id="btnLOGIN" name="btnLOGIN" onkeydown="vkeydownSubmit(event);" type="submit" value="로그인"/>
# <span class="option02"><a href="javascript:onclick_Find();" title="아이디 찾기">아이디</a> / <a href="javascript:onclick_FindPW();" title="비밀번호 찾기">비밀번호 찾기</a> <i class="bar">|</i> <a href="javascript:onclick_Join();" title="회원가입"><strong>회원가입</strong></a> </span>
# <script type="text/javascript">
#                                 //<![CDATA[
#                                     initLogin();
#                                     nateLogin = new NateLogin('f_login', 'btnLOGIN', 'xo.nate.com/servlets/EncLoginServlet', loginBoxName, '비밀번호');
#                                 //]]>
#                                 </script>
# </fieldset>
# </form>
# <div class="overlay_info type_security" id="layerXKDisabled" style="display: none">
# <div class="layer_content"></div>
# </div>
# <div class="overlay_info nHide" id="divNateOn">
# <p>웹 네이트온 로그인은 설치가 필요 없는<br/>가벼운 네이트온이 네이트 로그인 만으로<br/>함께 로그인 되는 편리한 기능입니다.</p>
# <a href="//nateonweb.nate.com/nateon/download_web.php" onmousedown="nc('NLI75')" title="웹 네이트온이란?">웹 네이트온이란?</a>
# <button class="close" onclick="closeWebNateOnInfo()" title="알림 레이어 닫기" type="button" value="알림 레이어 닫기">알림 레이어 닫기</button>
# </div>
# <div class="overlay_info type_saveid nHide">
# <p>개인정보 보호를 위해<br/>개인PC에서만<br/>사용해 주세요. <a href="https://helpdesk.nate.com/web/faq-detail?faqId=KNOW0000000038&amp;subNodeId=NODE0000000006&amp;keyword=%EB%A1%9C%EA%B7%B8%EC%9D%B8%EC%9C%A0%EC%A7%80&amp;pageNo=1" onmousedown="nc('NLI33');" target="_blank" title="도움말보기">도움말보기 <i class="icon_arrow_right_red"></i></a></p>
# <button class="icon_x_black" onclick="closeKeepLoginLayer()" onmousedown="nc('NLI32');" title="알림 레이어 닫기" type="button" value="알림 레이어 닫기">알림 레이어 닫기</button>
# </div>
# </div>
# <hr/>
# <h2>컨텐츠 영역</h2>
# <div class="area_news" id="news_area">
# <h3>뉴스</h3>
# <div class="menu" id="newsTabMenu">
# <h4 class="menu01 on" id="newstab1"><a href="//news.nate.com/" onclick="newsBox.clickTabLink('tab1_set1');return false;" title="뉴스탭 열기">뉴스</a></h4>
# <h4 class="menu02" id="newstab2"><a href="//sports.news.nate.com/" onclick="newsBox.clickTabLink('tab2_spo');return false;" title="스포츠탭 열기">스포츠</a></h4>
# <h4 class="menu03" id="newstab3"><a href="//news.nate.com/ent/section?mid=e0100;" onclick="newsBox.clickTabLink('tab3_ent');return false;" title="연예탭 열기">연예</a></h4>
# <h4 class="menu04" id="newstab4" style="display:none;"></h4>
# <h4 class="menu05" id="newstab5"><a href="//news.nate.com/rank/?mid=n1000" onclick="newsBox.clickTabLink('tab5_ranking');return false;" title="랭킹뉴스탭 열기">랭킹뉴스</a></h4>
# </div>
# <div class="content type_news" id="newsContType" onfocusin="newsBox.rollingStop();" onfocusout="newsBox.rollingStart();">
# <div class="tabCnt">
# <div class="rankBox" id="div_rank_sisa"></div>
# <div class="rankBox" id="div_rank_spo"></div>
# <div class="rankBox" id="div_rank_ent"></div>
# <ul class="type_thumb type02" id="newsImg_ul_1">
# <li id="newsImg0">
# <a href="//ps.news.nate.com/photo/slideShow?cid=1018868" onclick="setTabInfo();ndrclick('MEF01', 'NH_01_01_01-20231016100416');" target="_self">
# <em class="icon slide">슬라이드</em>
# <span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2023/10/16/1697415063_364.png" width="168"/></span>
# <span class="txt">"김기현 대표 쫓겨나겠네ㅜㅜ"</span>
# </a>
# </li>
# <li id="newsImg1">
# <a href="//tv.nate.com/clip/4857715" onclick="setTabInfo();ndrclick('MEF02', 'NH_03_01_01-20231016095714');" target="_self">
# <em class="icon play">동영상</em>
# <span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2023/10/16/1697417720_812.jpg" width="168"/></span>
# <span class="txt">3남매맘 하림, 잔잔한 리키와 균열? "직직 자극 원해"</span>
# </a>
# </li>
# </ul>
# <ul class="type_text" id="newsTxt_ul_1">
# <li id="newsTxt_li_0"><strong><a href="//news.nate.com/section?mid=n0300&amp;n=716660#cid716660" onclick="setTabInfo();ndrclick('MEB23', 'NH_01_02_01-20231016100106');" target="_self">4000원 인공눈물, 내년엔 4만원…건보 적용 안 한다</a></strong></li>
# <li id="newsTxt_li_1"><a href="//news.nate.com/section?mid=n0300&amp;n=748838#cid748838" onclick="setTabInfo();ndrclick('MEB25', 'NH_01_02_05-20231016085321');" target="_self">총선 눈치? 정부, 인상률 등 숫자 없는 연금개혁안 낸다</a></li>
# <li id="newsTxt_li_2"><a href="//news.nate.com/section?mid=n0300&amp;n=995762#cid995762" onclick="setTabInfo();ndrclick('MEB27', 'NH_01_02_08-20231016091225');" target="_self">50년간 생활물가 변화는?…라면 8배·소주 14배로 올라</a></li>
# <li id="newsTxt_li_3"><a href="//sports.news.nate.com/soccer/#cid647355" onclick="setTabInfo();ndrclick('MEB29', 'NH_02_02_02-20231016090531');" target="_self">'대구 태양의 아들' 이근호 공식은퇴 발표 "20년 사랑 진심으로 감사…남은 5경기 멋지게 마무리"</a></li>
# <li id="newsTxt_li_4"><a href="//news.nate.com/view/20231016n07958" onclick="setTabInfo();ndrclick('MEC61', 'NH_03_02_01-20231016095959');" target="_self">백종원, 심정지 의식 잃은 사람 구했다…"누구나 할 수 있는 일"</a></li>
# </ul>
# <ul class="type_text" id="newsTxt_ul_2">
# <li id="newsTxt_li_5"><strong><a href="//news.nate.com/hissue/clstList?mid=n0309&amp;isq=10477&amp;n=838426#cid838426" onclick="setTabInfo();ndrclick('MEB31', 'NH_01_02_02-20231016095010');" target="_self">집주인 "5억 토해냈어요"…재계약 10건 중 4건 '역전세'</a></strong></li>
# <li id="newsTxt_li_6"><a href="//news.nate.com/view/20231016n07297" onclick="setTabInfo();ndrclick('MEB33', 'NH_01_03_01-20231016095523');" target="_self">"다음 차도 테슬라" 하마스 100발 총격에 난도질…차주는 살았다</a></li>
# <li id="newsTxt_li_7"><a href="//news.nate.com/hissue/clstList?mid=n0208&amp;isq=11050&amp;n=1016527#cid1016527" onclick="setTabInfo();ndrclick('MEB35', 'NH_01_03_02-20231016095523');" target="_self">"검찰입니다", 이 한마디에 당하는 보이스피싱 급증</a></li>
# <li id="newsTxt_li_8"><a href="//sports.news.nate.com/hissue/clstList?mid=s0106&amp;isq=8588&amp;n=630749#cid630749" onclick="setTabInfo();ndrclick('MEB37', 'NH_02_02_01-20231016083136');" target="_self">LG 4천원 동결, 두산 9천원→1만원 인상…같은 잠실구장 맞나요?</a></li>
# <li id="newsTxt_li_9"><a href="//news.nate.com/hissue/clstList?mid=e0100&amp;isq=7377&amp;n=1018845#cid1018845" onclick="setTabInfo();ndrclick('MEC63', 'NH_03_02_01-20231016092452');" target="_self">모두 울었다…이상민 "母, 치매로 행방불명→사랑해" 눈물</a></li>
# </ul>
# <ul class="type_text nHide" id="newsTxt_ul_3">
# <li id="newsTxt_li_10"></li>
# <li id="newsTxt_li_11"></li>
# <li id="newsTxt_li_12"></li>
# <li id="newsTxt_li_13"></li>
# <li id="newsTxt_li_14"></li>
# </ul>
# <ul class="type_thumb type01" id="newsImg_ul_2">
# <li id="newsImg2">
# <a href="//sports.news.nate.com/abrbaseball/photo?page=1&amp;cid=1018854&amp;fix=1018854" onclick="setTabInfo();ndrclick('MEF03', 'NH_02_01_03-20231016085714');" target="_self">
# <em class="icon slide">슬라이드</em>
# <span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2023/10/16/1697414192_765.jpg" width="168"/></span>
# <span class="txt">이정후, 여성 감독과 호흡? 알리사 나켄 SF와 감독 면접</span>
# </a>
# </li>
# <li id="newsImg3">
# <a href="//news.nate.com/view/20231016n06986" onclick="setTabInfo();ndrclick('MEF04', 'NH_01_04_01-20231016095238');" target="_self">
# <span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2023/10/16/1697417538_308.jpg" width="168"/></span>
# <span class="txt">대학 학식에서 벌레·못 등 이물질 나와…'논란'</span>
# </a>
# </li>
# <li id="newsImg4">
# <a href="//news.nate.com/view/20231016n02972" onclick="setTabInfo();ndrclick('MEF05', 'NH_01_04_01-20231016074852');" target="_self">
# <span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2023/10/16/1697410125_397.jpg" width="168"/></span>
# <span class="txt">'불륜·증거수집'…흥신소가 몰래 찍은 사진 SNS에 버젓이</span>
# </a>
# </li>
# </ul>
# <div class="overlay_plus type01" id="newsPlusLayer" style="display:none">
# <div class="plus_content">
# <iframe frameborder="0" height="470" id="newsIfr" scrolling="no" src="about:blank" title="뉴스플러스 아이프레임" width="304"></iframe>
# <button class="close" onclick="closeNewsPlus();ndrclick('MEC49','');" title="뉴스플러스 레이어 닫기" type="button" value="뉴스플러스 레이어 닫기">뉴스플러스 레이어 닫기</button>
# </div>
# </div>
# </div>
# <div class="bizCnt">
# <div class="isKeyword">
# <h4>실시간 이슈 키워드</h4>
# <ol class="isKeywordList" id="olLiveIssueKeyword">
# <li>
# <span class="num_rank">1</span>
# <a class="ik" href="https://news.nate.com/search?q=안연홍 재혼" onclick="newsBox.clickSearchKeyword('안연홍 재혼');return false;" onmousedown="nc('MEH01')">
# <span class="txt_rank">안연홍 재혼</span>
# <span class="fc same"><span class="nHide">동일</span></span>
# </a>
# </li>
# <li>
# <span class="num_rank">2</span>
# <a class="ik" href="https://news.nate.com/search?q=신도시 남양주 왕숙" onclick="newsBox.clickSearchKeyword('신도시 남양주 왕숙');return false;" onmousedown="nc('MEH02')">
# <span class="txt_rank">신도시 남양주 왕숙</span>
# <span class="fc new"><span class="nHide">new</span></span>
# </a>
# </li>
# <li>
# <span class="num_rank">3</span>
# <a class="ik" href="https://news.nate.com/search?q=의대 정원 1000명" onclick="newsBox.clickSearchKeyword('의대 정원 1000명');return false;" onmousedown="nc('MEH03')">
# <span class="txt_rank">의대 정원 1000명</span>
# <span class="fc new"><span class="nHide">new</span></span>
# </a>
# </li>
# <li>
# <span class="num_rank">4</span>
# <a class="ik" href="https://news.nate.com/search?q=구급차 타고 행사장" onclick="newsBox.clickSearchKeyword('구급차 타고 행사장');return false;" onmousedown="nc('MEH04')">
# <span class="txt_rank">구급차 타고 행사장</span>
# <span class="fc down"><span class="nHide">하락</span>1</span>
# </a>
# </li>
# <li>
# <span class="num_rank">5</span>
# <a class="ik" href="https://news.nate.com/search?q=김주형 슈라이너스 칠드런스" onclick="newsBox.clickSearchKeyword('김주형 슈라이너스 칠드런스');return false;" onmousedown="nc('MEH05')">
# <span class="txt_rank">김주형 슈라이너스 칠드런스</span>
# <span class="fc new"><span class="nHide">new</span></span>
# </a>
# </li>
# </ol>
# <form accept-charset="euc-kr" action="https://news.nate.com/search" id="frmKeyword" name="frmKeyword" onsubmit="return false">
# <input id="bizq" name="q" type="hidden" value=""/>
# </form>
# </div>
# <div class="adBox"></div>
# <div class="todayBox" id="divBox">
# <h3>
# <span class="nHide">오늘 &amp; 기타정보</span>
# <strong class="tdate">10.16</strong> 월요일
# 					</h3>
# <h4 class="nHide">날씨</h4>
# <a class="tempinfo" href="#" onmousedown="nc('MEH10');">
# <div>
# <div class="misc">
# <img alt="맑음" height="42" src="//main2.nateimg.co.kr/img/v7/weather3/52x52_am_01.png" width="42"/>
# </div>
# <div class="temperature">
# <span class="tempdata">13</span>
# </div>
# <div class="rbox">
# <span class="degree">℃</span>
# <span class="local">서울</span>
# </div>
# </div>
# </a>
# <div class="plusinfo">
# <p class="rangeTemp">어제보다 <span>
#
#
#
#
#
# 								-1
#
# 						</span></p>
# <a href="http://news.nate.com/weather/airPollution?type=pm10" onmousedown="nc('MEH11');"><p class="dust">미세먼지 <span class="pol2">보통</span></p></a>
# </div>
# </div>
# </div>
# <dl class="content_recommend">
# <dt id="dtNewsRecomm"><em>뉴스</em></dt>
# <dd id="newsRecommend">
# <a href="//news.nate.com/comment?mid=n1500" onmousedown="nc('MEF32');setTabInfo();">투데이베플</a>
# <a href="//news.nate.com/ent/idol24" onmousedown="nc('MEF33');setTabInfo();">아이돌24시</a>
# <a href="//news.nate.com/hissue/clstList?mid=e0103&amp;isq=7376" onmousedown="nc('MEF34');setTabInfo();">드라마 모아보기</a>
# <a href="//news.nate.com/hissue/clstList?mid=e0103&amp;isq=7377" onmousedown="nc('MEF35');setTabInfo();">예능 모아보기</a>
# </dd>
# </dl>
# </div>
# <div class="nav" id="newsOptBtn">
# <span id="newsMoreArea"><em>1</em> / 6</span>
# <button class="pause" id="newsRollingBtn" onclick="newsBox.changeRolling();" title="자동전환기능 정지" type="button" value="자동전환기능 정지">자동전환기능 정지</button>
# <button class="prev" onclick="ndrclick('MEC42');newsBox.showPreNext('P');" title="이전 뉴스 보기" type="button" value="이전 뉴스 보기">이전 뉴스 보기</button>
# <button class="next" onclick="ndrclick('MEC43');newsBox.showPreNext('N');" title="다음 뉴스 보기" type="button" value="다음 뉴스 보기">다음 뉴스 보기</button>
# </div>
# <div id="newsNotice"></div>
# <div class="overlay_ticker" id="ticker_lyr" style="display:none">
# <div class="ticker_content">
# <iframe frameborder="0" height="318" id="ticker_ifm" scrolling="no" src="about:blank" title="티커 아이프레임" width="728"></iframe>
# <button class="close" onclick="nateonTickerClose();" title="티커 닫기" type="button" value="티커 닫기">티커 닫기</button>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# 				//<![CDATA[
# 					loadSpecialBiRolling();
# 				//]]>
# 				</script>
# <!-- tiles:insertAttribute name="NateQ" /-->
# <div class="area_contents" id="divContentsUpper">
# <h3>컨텐츠</h3>
# <div class="menu">
# <h4 class="menu01 on"><a href="//pann.nate.com/talk/ranking" onclick="objPannArea.clickTab(0);return false;" onmousedown="nc('PAN60')" title="Top랭킹">Top랭킹</a></h4>
# <h4 class="menu02"><a href="//pann.nate.com/talk/c20025" onclick="objPannArea.clickTab(1);return false;" onmousedown="nc('PAN61')" title="결시친">결시친</a></h4>
# <h4 class="menu03"><a href="//pann.nate.com/talk/c20038" onclick="objPannArea.clickTab(2);return false;" onmousedown="nc('PAN62')" title="10대톡">10대톡</a></h4>
# <h4 class="menu04"><a href="//pann.nate.com/talk/c20028" onclick="objPannArea.clickTab(3);return false;" onmousedown="nc('PAN63')" title="연예톡">연예톡</a></h4>
# <h4 class="menu05"><a href="//pann.nate.com/talk/c20019" onclick="objPannArea.clickTab(4);return false;" onmousedown="nc('PAN64')" title="회사톡">회사톡</a></h4>
# </div>
# <div class="content" id="pannList">
# <ol class="rank">
# <li>
# <div class="list_box">
# <span class="num_rank">1</span>
# <span class="emph"><span class="nHide">댓글수</span>(181)</span>
# <a class="link" href="https://pann.nate.com/talk/371191320" onmousedown="nc('PAO80');objPannArea.clickContents(0);">엄마들 모임 회비문제. 제가 잘못했나요? +후기!</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">2</span>
# <span class="emph"><span class="nHide">댓글수</span>(133)</span>
# <a class="link" href="https://pann.nate.com/talk/371194899" onmousedown="nc('PAO81');objPannArea.clickContents(0);">후기) 밤중 연락하던 여사친 결론</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">3</span>
# <span class="emph"><span class="nHide">댓글수</span>(112)</span>
# <a class="link" href="https://pann.nate.com/talk/371191485" onmousedown="nc('PAO82');objPannArea.clickContents(0);">정국이랑 뉴진스 디토 챌린지뜸</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">4</span>
# <span class="emph"><span class="nHide">댓글수</span>(78)</span>
# <a class="link" href="https://pann.nate.com/talk/371193791" onmousedown="nc('PAO83');objPannArea.clickContents(0);">제가 시누이랑 시댁식구한테 선넘은건가요?</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">5</span>
# <span class="emph"><span class="nHide">댓글수</span>(163)</span>
# <a class="link" href="https://pann.nate.com/talk/371192612" onmousedown="nc('PAO84');objPannArea.clickContents(0);">근데 여친있는 남돌 파는건 대체 뭔 심리임??</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">6</span>
# <span class="emph"><span class="nHide">댓글수</span>(70)</span>
# <a class="link" href="https://pann.nate.com/talk/371193346" onmousedown="nc('PAO85');objPannArea.clickContents(0);">동료의 식탐이 문제인지 제가 이기적인지 봐주세요</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">7</span>
# <span class="emph"><span class="nHide">댓글수</span>(562)</span>
# <a class="link" href="https://pann.nate.com/talk/371191721" onmousedown="nc('PAO86');objPannArea.clickContents(0);">교사 입장에서 국제결혼 너무 끔찍해요</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">8</span>
# <span class="emph"><span class="nHide">댓글수</span>(71)</span>
# <a class="link" href="https://pann.nate.com/talk/371191765" onmousedown="nc('PAO87');objPannArea.clickContents(0);">와 있지 유나 렌즈</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">9</span>
# <span class="emph"><span class="nHide">댓글수</span>(73)</span>
# <a class="link" href="https://pann.nate.com/talk/371192703" onmousedown="nc('PAO88');objPannArea.clickContents(0);">제니가 대학축제 때 쓴 글ㅋㅋㅋㅋㅋㅋㅋ</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">10</span>
# <span class="emph"><span class="nHide">댓글수</span>(439)</span>
# <a class="link" href="https://pann.nate.com/talk/371192275" onmousedown="nc('PAO89');objPannArea.clickContents(0);">솔직히 남돌 노래 거르게 된거 엔시티 책임이 큼</a>
# </div>
# </li>
# </ol>
# <ol class="rank" start="11">
# <li>
# <div class="list_box">
# <span class="num_rank">11</span>
# <span class="emph"><span class="nHide">댓글수</span>(56)</span>
# <a class="link" href="https://pann.nate.com/talk/371193408" onmousedown="nc('PAO90');objPannArea.clickContents(0);">이런사람 대중교통 안탔으면 좋겠다</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">12</span>
# <span class="emph"><span class="nHide">댓글수</span>(92)</span>
# <a class="link" href="https://pann.nate.com/talk/371191914" onmousedown="nc('PAO91');objPannArea.clickContents(0);">르세라핌 염색 어때</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">13</span>
# <span class="emph"><span class="nHide">댓글수</span>(48)</span>
# <a class="link" href="https://pann.nate.com/talk/371192951" onmousedown="nc('PAO92');objPannArea.clickContents(0);">케이스티파이 극혐인점</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">14</span>
# <span class="emph"><span class="nHide">댓글수</span>(49)</span>
# <a class="link" href="https://pann.nate.com/talk/371193511" onmousedown="nc('PAO93');objPannArea.clickContents(0);">추가글) 데이트중 혼자 길 건너는 남친</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">15</span>
# <span class="emph"><span class="nHide">댓글수</span>(48)</span>
# <a class="link" href="https://pann.nate.com/talk/371192880" onmousedown="nc('PAO94');objPannArea.clickContents(0);">실시간 장원영 스타일링 ㄷㄷ</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">16</span>
# <span class="emph"><span class="nHide">댓글수</span>(37)</span>
# <a class="link" href="https://pann.nate.com/talk/371191708" onmousedown="nc('PAO95');objPannArea.clickContents(0);">심각한 제베원 사생 현 상황</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">17</span>
# <span class="emph"><span class="nHide">댓글수</span>(52)</span>
# <a class="link" href="https://pann.nate.com/talk/371193888" onmousedown="nc('PAO96');objPannArea.clickContents(0);">로제 솔로앨범 곧 나올듯</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">18</span>
# <span class="emph"><span class="nHide">댓글수</span>(39)</span>
# <a class="link" href="https://pann.nate.com/talk/371197449" onmousedown="nc('PAO97');objPannArea.clickContents(0);">이거 남미새 관상이라는데 ㅈㄴ웃김</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">19</span>
# <span class="emph"><span class="nHide">댓글수</span>(33)</span>
# <a class="link" href="https://pann.nate.com/talk/371195633" onmousedown="nc('PAO98');objPannArea.clickContents(0);">아빠가 묶어준 별나라 공주님 머리</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="num_rank">20</span>
# <span class="emph"><span class="nHide">댓글수</span>(190)</span>
# <a class="link" href="https://pann.nate.com/talk/371193161" onmousedown="nc('PAO99');objPannArea.clickContents(0);">나 진짜 ㅈㄴ 남미새인거 인정하는데 솔직히</a>
# </div>
# </li>
# </ol>
# </div>
# <!-- nav -->
# <div class="nav">
# <span><a href="//pann.nate.com/" onmousedown="nc('PAN65')">판홈</a> <i>|</i> <em>1</em> / 5</span>
# <button class="prev" onclick="objPannArea.clickButton('P');" onmousedown="nc('PAN98')" title="이전 컨텐츠 보기" type="button" value="이전 컨텐츠 보기">이전 컨텐츠 보기</button>
# <button class="next" onclick="objPannArea.clickButton('N');" onmousedown="nc('PAN99')" title="다음 컨텐츠 보기" type="button" value="다음 컨텐츠 보기">다음 컨텐츠 보기</button>
# </div>
# <!-- //nav -->
# </div>
# <div class="area_issue" id="divIssueUp">
# <h3>키워드</h3>
# <div class="menu">
# <div class="keyword_list">
# <div class="list_top">
# <h4 class="menu08"><a href="javascript:issueContents.clickIssueUpNateTv(0)" onmousedown="nc('CTG08')">TV</a></h4>
# <h4 class="menu01 on"><a href="javascript:issueContents.clickIssueUpCategory(1, 0)" onmousedown="nc('CTG01');">여행/맛집</a></h4>
# <h4 class="menu02"><a href="javascript:issueContents.clickIssueUpCategory(2, 0)" onmousedown="nc('CTG02');">뷰티</a></h4>
# <h4 class="menu03"><a href="javascript:issueContents.clickIssueUpCategory(3, 0)" onmousedown="nc('CTG03');">푸드</a></h4>
# <h4 class="menu04"><a href="javascript:issueContents.clickIssueUpToonNBook()" onmousedown="nc('CTG09');">만화/웹툰</a></h4>
# <h4 class="menu05"><a href="javascript:issueContents.clickIssueUpCategory(5, 0)" onmousedown="nc('CTG05');">패션</a></h4>
# <h4 class="menu06"><a href="javascript:issueContents.clickIssueUpCategory(6, 0)" onmousedown="nc('CTG06');">라이프</a></h4>
# <h4 class="menu07" id="issueTabShopping"><a href="javascript:issueContents.clickIssueUpShopping()" onmousedown="nc('CTG07');">쇼핑</a></h4>
# </div>
# <div class="list_btm" id="divIssueKeyword">
# <h5 class="on"><a href="javascript:issueContents.clickIssueUpCategory(1, 0)" onmousedown="nc('CCA01');">할머니 솜씨</a></h5><h5><a href="javascript:issueContents.clickIssueUpCategory(1, 1)" onmousedown="nc('CCA02');">대학가 맛집</a></h5><h5><a href="javascript:issueContents.clickIssueUpCategory(1, 2)" onmousedown="nc('CCA03');">서울 3호선의 맛</a></h5><h5><a href="javascript:issueContents.clickIssueUpCategory(1, 3)" onmousedown="nc('CCA04');">등산로 식당</a></h5><h5><a href="javascript:issueContents.clickIssueUpCategory(1, 4)" onmousedown="nc('CCA05');">파스타 데이트</a></h5><h5><a href="javascript:issueContents.clickIssueUpCategory(1, 5)" onmousedown="nc('CCA06');">불 맛 불 향</a></h5><h5><a href="javascript:issueContents.clickIssueUpCategory(1, 6)" onmousedown="nc('CCA07');">현지인 추천</a></h5></div>
# </div>
# </div>
# <div class="content" id="divIssueUpContents">
# <ul><li class="type_text"><a href="javascript:;" onclick="issueContents.clickDetailInfo('1', '0', '0');" onmousedown="nc5('CAA01','56090','65','1');nc2('CAA01');"><span class="title">정이 느껴지는<br>달인의 비빔국수<br/></br></span><span class="content">순한 양념이라<br/>먹다 보면 입 안에<br/>여운이 남는 맛</span></a><cite>여행/맛집 <em>추천콘텐츠</em></cite></li><li><a href="javascript:;" onclick="issueContents.clickDetailInfo('1', '0', '1');" onmousedown="nc5('CAA02','56090','65','2');nc2('CAA01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2023/10/1697156974486.jpg" width="169"/></span><span class="title"><strong>재방문 의사 있는</strong><br/><strong>'할마카세' 가게</strong></span></a><cite>여행/맛집 <em>추천콘텐츠</em></cite></li><li><a href="javascript:;" onclick="issueContents.clickDetailInfo('1', '0', '2');" onmousedown="nc5('CAA03','56090','65','3');nc2('CAA01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2023/10/1697156979448.jpg" width="169"/></span><span class="title">살 통통한 닭발을<br/>푸짐히 퍼 주는 곳</span></a><cite>여행/맛집 <em>추천콘텐츠</em></cite></li><li><a href="javascript:;" onclick="issueContents.clickDetailInfo('1', '0', '3');" onmousedown="nc5('CAA04','56090','65','4');nc2('CAA01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2023/10/1697156994978.jpg" width="169"/></span><span class="title"><strong>후회 없는 선택한</strong><br/><strong>시장 맛집 추천!</strong></span></a><cite>여행/맛집 <em>추천콘텐츠</em></cite></li><li class="type_wide"><a href="javascript:;" onclick="issueContents.clickDetailInfo('1', '0', '4');" onmousedown="nc5('CAA05','56090','65','5');nc2('CAA01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2023/10/1697156984139.jpg" width="356"/></span><span class="title"><strong>자극적이지 않게 적당히 맵고</strong><br/><strong>식감 부드러운 오리고기</strong></span></a><cite>여행/맛집 <em>추천콘텐츠</em></cite></li><li><a href="javascript:;" onclick="issueContents.clickDetailInfo('1', '0', '5');" onmousedown="nc5('CAA06','56090','65','6');nc2('CAA01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2023/10/1697177559846.jpg" width="169"/></span><span class="title"><strong>오랜 세월 동안</strong><br/><strong>언제나 인기인 듯</strong></span></a><cite>여행/맛집 <em>추천콘텐츠</em></cite></li><li><a href="javascript:;" onclick="issueContents.clickDetailInfo('1', '0', '6');" onmousedown="nc5('CAA07','56090','65','7');nc2('CAA01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2023/10/1697177570690.jpg" width="169"/></span><span class="title">사장님 인심이<br/>느껴지는 단골집</span></a><cite>여행/맛집 <em>추천콘텐츠</em></cite></li><li><a href="javascript:;" onclick="issueContents.clickDetailInfo('1', '0', '7');" onmousedown="nc5('CAA08','56090','65','8');nc2('CAA01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2023/10/1697177564565.jpg" width="169"/></span><span class="title"><strong>꼭 먹어봐야 할</strong><br/><strong>원조 본연의 맛</strong></span></a><cite>여행/맛집 <em>추천콘텐츠</em></cite></li><li><a href="javascript:;" onclick="issueContents.clickDetailInfo('1', '0', '8');" onmousedown="nc5('CAA09','56090','65','9');nc2('CAA01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2023/10/1697177574846.jpg" width="169"/></span><span class="title">친절하신 할머니가<br/>내주는 한 그릇</span></a><cite>여행/맛집 <em>추천콘텐츠</em></cite></li><li><a href="javascript:;" onclick="issueContents.clickDetailInfo('1', '0', '9');" onmousedown="nc5('CAA10','56090','65','10');nc2('CAA01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2023/10/1697180351410.jpg" width="169"/></span><span class="title">꿀떡꿀떡 들어가<br/>추억 되새김질?</span></a><cite>여행/맛집 <em>추천콘텐츠</em></cite></li><li class="type_text"><a href="javascript:;" onclick="issueContents.clickDetailInfo('1', '0', '10');" onmousedown="nc5('CAA11','56090','6 ...
# <div class="content type_err nHide" id="emergencyLayer">
# <h4 class="">쇼핑탭 점검중</h4>
# <p>불편을 드려 죄송합니다.<br/>더 좋은 서비스를 위해<br/><strong>쇼핑탭은 지금 점검</strong> 중입니다.</p>
# <a href="https://shopping.nate.com/">네이트 쇼핑으로 바로가기</a>
# </div>
# <div class="overlay_ally" style="display:none;"></div>
# <div class="movplay" id="movieSec">
# <div class="issuemov">
# <div id="divPlayer"></div>
# <a class="btn_view_detail" href="" id="movieDetailLink" onmousedown="javascript:nc('MVA02');" target="" title="광고 자세히보기">광고 자세히보기</a>
# <button class="btn_x_small_white" onclick="issueContents.closeMovie();" onmousedown="nc('CZA02')" title="동영상 플레이 레이어 닫기" type="button" value="동영상 플레이 레이어 닫기">동영상 플레이 레이어 닫기</button>
# </div>
# <span class="shadow"></span>
# </div>
# <div class="content type_err tbe nHide" id="divToonNBookErrLayer">
# <h4 class="">만화/웹툰탭 점검중</h4>
# <p>불편을 드려 죄송합니다.<br/>더 좋은 서비스를 위해<br/><strong>만화/웹툰탭은 지금 점검</strong> 중입니다.</p>
# <a href="https://toonnbook.nate.com">네이트 툰앤북으로 바로가기</a>
# </div>
# </div>
# <div class="area_best">
# <h3>베스트 컨텐츠</h3>
# <h4>당신이 놓친 오늘의<br/>추천 콘텐츠</h4>
# <ul>
# <li>
# <a href="https://view.nate.com/fun/view/85158/" onmousedown="nc('RCM01');" title="한국인이라면 유독 좋아하는 식감?">
# <span class="thumb">
# <img alt="한국인이라면 유독 좋아하는 식감?" height="70" src="//main.nateimg.co.kr/img/cms/content_pool/2023/10/1697075296838.jpg" width="94"/></span>
# <span class="title">
# 						한국인이라면 유독 좋아하는 식감?
# 						</span>
# <cite>
# 						 펀
# 						</cite>
# </a>
# </li>
# <li>
# <a href="https://view.nate.com/travel/view/59188/" onmousedown="nc('RCM02');" title="모두의 해장 책임질 콩나물국밥 Top 5">
# <span class="thumb">
# <img alt="모두의 해장 책임질 콩나물국밥 Top 5" height="70" src="//main.nateimg.co.kr/img/cms/content_pool/2023/10/1697076392727.jpg" width="94"/></span>
# <span class="title">
# 						모두의 해장 책임질 콩나물국밥 Top 5
# 						</span>
# <cite>
# 						 맛집
# 						</cite>
# </a>
# </li>
# <li>
# <a href="https://view.nate.com/enter/view/86619/" onmousedown="nc('RCM03');" title="3일간 물 안 마시고 근육 키운 배우">
# <span class="thumb">
# <img alt="3일간 물 안 마시고 근육 키운 배우" height="70" src="//main.nateimg.co.kr/img/cms/content_pool/2023/10/1697076380594.jpg" width="94"/></span>
# <span class="title">
# 						3일간 물 안 마시고 근육 키운 배우
# 						</span>
# <cite>
# 						 스타
# 						</cite>
# </a>
# </li>
# <li>
# <a href="https://news.nate.com/view/20231011n26890" onmousedown="nc('RCM04');" title="언제나 감탄 나오는 '만찢녀' 비주얼">
# <span class="thumb">
# <img alt="언제나 감탄 나오는 '만찢녀' 비주얼" height="70" src="//main.nateimg.co.kr/img/cms/content_pool/2023/10/1697076364342.jpg" width="94"/></span>
# <span class="title">
# 						언제나 감탄 나오는 '만찢녀' 비주얼
# 						</span>
# <cite>
# 						 스타
# 						</cite>
# </a>
# </li>
# </ul>
# </div>
# <div class="area_ranking">
# <h3>랭킹</h3>
# <div class="menu">
# <h4 class="menu04">Fun &amp; Fun 해</h4>
# </div>
# <div class="content" onmouseout="nateRanking.startRolling()" onmouseover="nateRanking.stopRolling()">
# <ul class="type_thumb">
# <li>
# <a href="https://fortune.nate.com/content/contentInfo.nate?searchcontscd=CT001377" onmousedown="nc('RKN91')" title="운세ㅣ천지인 궁합"><span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/cms/content_pool/2023/10/1697092564129.gif"/></span>
# <span class="title">운세ㅣ천지인 궁합<span class="cite">우린 잘 만난 인연일까</span></span></a>
# </li>
# <li>
# <a href="https://fortune.nate.com/contents/freeunse/freeunseframe.nate?freeUnseId=today03" onmousedown="nc('RKN92')" title="운세ㅣ열두 띠로 보는"><span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/cms/content_pool/2023/10/1697092568403.gif"/></span>
# <span class="title">운세ㅣ열두 띠로 보는<span class="cite">2023년 10월 3주 운세</span></span></a>
# </li>
# <li>
# <a href="http://3e.nate.pupugame.com/" onmousedown="nc('RKN93')" title="삼국군영전W | 영웅이 되어"><span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/cms/content_pool/2023/10/1697092572838.jpg"/></span>
# <span class="title">삼국군영전W | 영웅이 되어<span class="cite">난세의 삼국을 통일하라!</span></span></a>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H040085841" onmousedown="nc('RKN94')" title="만화 | 절대 들키면 안 돼!"><span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/cms/content_pool/2023/10/1697092576978.png"/></span>
# <span class="title">만화 | 절대 들키면 안 돼!<span class="cite">이 회사에 좋아하는 사람이 있...</span></span></a>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H043628534" onmousedown="nc('RKN95')" title="웹툰｜격투기 여왕의 계약결혼"><span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/cms/content_pool/2023/10/1697092581276.png"/></span>
# <span class="title">웹툰｜격투기 여왕의 계약결혼<span class="cite">사모님은 챔피언</span></span></a>
# </li>
# </ul>
# </div>
# <div class="paging_slide">
# <span class="num_count_1"><em>1</em> / 2</span>
# <button class="btn prev" onclick="nateRanking.clickRankingBtn('P');" onmousedown="nc('RKN98');" title="이전" type="button">이전</button>
# <button class="btn next" onclick="nateRanking.clickRankingBtn('N');" onmousedown="nc('RKN99');" title="다음" type="button">다음</button>
# </div>
# </div>
# <hr/>
# <h2>쇼핑&amp; 광고 영역</h2>
# <div class="area_shopping" id="shopping" style="display:none">
# <h3>쇼핑</h3>
# <div class="mall1shop" id="shopitemMall">
# <h3 class="tab" id="mall1Title"><a class="link" href="http://shopping.nate.com" onmousedown="ndrclick2('NFA01')" target="_top">쇼핑홈</a></h3>
# <div class="shopmall" id="mall1Box"></div>
# <h3 class="tab" id="mall2Title"><a class="link" href="#" onmousedown="ndrclick2('NFC01')" target="_blank"></a></h3>
# <div class="shopmall nHide" id="mall2Box"></div>
# <h3 class="tab" id="mall3Title"><a class="link" href="#" onmousedown="ndrclick2('NFE01')" target="_blank"></a></h3>
# <div class="shopmall nHide" id="mall3Box"></div>
# <h3 class="tab" id="mall4Title"><a class="link" href="#" onmousedown="ndrclick2('NFG01')" target="_blank"></a></h3>
# <div class="shopmall nHide" id="mall4Box"></div>
# <div id="relShopping">
# <strong class="nHide">쇼핑 관련 리스트</strong>
# <div class="paging_slide">
# <button class="btn prev" id="shoppingPrev" onmousedown="ndrclick2('NFZ01')" title="이전" type="button">쇼핑 이전 내용</button>
# <button class="btn next" id="shoppingNext" onmousedown="ndrclick2('NFZ02')" title="다음" type="button">쇼핑 다음 내용</button>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# //<![CDATA[
#     var nDt = new Date();
#     var verShop = '' + (nDt.getMonth()+1) + nDt.getDate() + nDt.getHours() + nDt.getMinutes();
# //]]>
# </script>
# </div>
# <div class="area_shopping type_err" id="shopping_err" style="display:none">
# <h4 class="">쇼핑박스 점검중</h4>
# <p>불편을 드려 죄송합니다.<br>더 좋은 서비스를 위해<br/><strong>쇼핑박스는 지금 점검</strong> 중입니다.</br></p>
# <a href="http://shopping.nate.com">네이트 쇼핑으로 바로가기</a>
# </div>
# <div class="area_shopping_today">
# <!-- tiles:insertAttribute name="shopRecommendation" /-->
# </div>
# <div class="area_quick" id="divQuickMenu">
# <h3>퀵링크</h3>
# <div class="area_sktad01"></div>
# <ul>
# <li class="totop"><a href="javascript:;" onmousedown="nc('RAB15');"><span>맨위로</span></a></li>
# <li>
# <a href="https://tv.nate.com/" onmousedown="nc('RAB25');" title="네이트TV 서비스 가기">네이트TV</a>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/" onmousedown="nc('RAB24');" title="툰앤북 서비스 가기">툰앤북</a>
# </li>
# <li>
# <a href="https://mobile.nate.com/decorate/mvno/top" onmousedown="nc('RAB19');" title="컬러링 서비스 가기">컬러링</a>
# </li>
# <li>
# <a href="http://editor.nate.com/" onmousedown="nc('RAB23');" title="이슈UP추천 서비스 가기">이슈UP추천</a>
# </li>
# <li class="issue"><a href="javascript:;" onmousedown="nc('RAB08');">이슈<em class="issueup">UP</em></a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <div id="footer">
# <h2>푸터 영역</h2>
# <div class="notice">
# <h3><a href="https://helpdesk.nate.com/web/notice/main" onmousedown="nc('NFT01');">공지사항</a></h3>
# <a href="https://helpdesk.nate.com/web/notice/main-detail?id=8770" onmousedown="nc('NFT02');">뉴스를 즐기는 새로운 방법, ‘오늘의 Quiz’ 오픈 안내</a>
# </div>
# <dl>
# <dt>네이트 공용 푸터</dt>
# <dd>
# <a href="http://www.skcomms.co.kr/" onmousedown="nc('NFT21');">회사소개</a> <span>|</span>
# <a href="http://business.nate.com/" onmousedown="nc('NFT29');">광고문의</a> <span>|</span>
# <a href="/policy/legal.html" onmousedown="nc('NFT24');">서비스 약관</a> <span>|</span>
# <a href="/policy/privacy.html" onmousedown="nc('NFT25');"><strong>개인정보처리방침</strong></a> <span>|</span>
# <a href="/policy/youthpolicy.html" onmousedown="nc('NFT26');">청소년보호정책</a> <span>|</span>
# <a href="http://helpdesk.nate.com/" onmousedown="nc('NFT11');">고객센터</a> <span>|</span>
# <span class="copyright">© <a href="http://www.skcomms.co.kr/" onmousedown="nc('NFT41');" target="_blank"><strong><span class="sk">SK</span> Communications.</strong></a></span>
# </dd>
# </dl>
# <a class="view_all" href="/sitemap/index.html" onmousedown="nc('NFT12');">서비스 전체보기</a>
# </div>
# <hr/>
# <div id="adContainer">
# <h2>광고 영역</h2>
# <div class="area_ad01" id="ad_layer1"></div>
# <div class="area_ad02" id="ad_layer2">
# </div>
# <div class="area_adual">
# <div class="area_ad03">
# </div>
# <div class="area_ad04">
# </div>
# </div>
# <div class="area_ad05 nHide" id="leftAd05Cj">
# <a href="http://talkon.nate.com/service.html" onmousedown="nc('NBI11');" target="_blank"><img alt="게임할땐 토크온!" height="110" src="//main.nateimg.co.kr/img/v6/talkon_55x110.gif" width="55"/></a>
# </div>
# <div class="area_ad06"></div>
# <div class="area_sktad02"></div>
# <div class="area_ad09">
# <!-- iframe id="ifrm_ad09" name="ifrm_ad09" frameborder="0" width="728" height="90" scrolling="no" src="about:blank" title="광고"></iframe -->
# </div>
# <div class="area_ad10">
# <a href="https://nateonweb.nate.com/" onmousedown="setNcCode('NAA21|NAA22',iSvcSeqC-1);"><img alt=" 네이트온" height="90" src="//main.nateimg.co.kr/img/cms/content_pool/2023/07/1688716590337.png" width="332"/></a>
# </div>
# <div id="ad_layer3"></div>
# <div id="ad_layer4" style="display:none;"></div>
# </div>
# </div>
# <div id="cbContainer">
# <div class="area_ad08" id="cbLayer" style="display: none">
# <span class="commTxt">한눈에 보는 오늘 <em>NATE</em>와 함께 하루를 시작하세요.</span>
# <a href="javascript:;" id="cbLayerLink" title="NATE를 시작페이지로">NATE를 시작페이지로</a>
# </div>
# </div>
# </div>
# <div class="setting_moblie" id="plus_footer" style="display: none"></div>
# <span id="layerTemp"></span>
# <script src="/js/common/natead_081.js?v=20200206_02" type="text/javascript"></script>
# <script type="text/javascript">
#
# 	if (isiPad) {
# 		document.write('<img src="//stat.nate.com/stat/stat.tiff?cp_url=[www_ndr.nate.com/ipad/]" width="0"  height="0" border="0" alt="" />');
# 	}
#
# </script>
# <script type="text/javascript">
# //<![CDATA[
# try{
#
# 	var contentsUpperTabMenu = ["null", "http://pann.news.nate.com/info", "//main.nateimg.co.kr/img/cms/content_pool/2015/05/trend_gray.gif", "//main.nateimg.co.kr/img/cms/content_pool/2015/05/trend_black.gif" ];
# 	var contentsUpperTopLink = [["null", "http://www.nate.com/?f=bi"],["null", "http://www.nate.com/?f=bi"],["null", "http://www.nate.com/?f=bi"],["null", "http://www.nate.com/?f=bi"]];
# 	var contentsUpperSecondPannTitle = ["톡커들의 선택"];
#
# }catch (e) { }
# //]]>
# </script>
# <!--natemain-->
# <script type="text/javascript">//<![CDATA[
#  CFN_type = ''; CFN_id = ''; CFN_cn = ''; CFN_cmn = ''; CFN_link = ''; CFN_link_id = ''; id = (CFN_type == 'N') ? CFN_id : CFN_link_id; cyid = (CFN_type == 'C') ? CFN_id : CFN_link_id; name = CFN_cn; isEmpas = ('' == '1'); refererDomain = ''; CFN_cust_tp_cd = ''; CFN_sex_cd = ''; loginType = ''; isMobile = 'F'; CFN_link_cust_tp_cd = ''; CFN_link_stat_cd = ''; var ndrLoginStatus = (isNateLogin) ? 'login' : ((bLogout) ? 'byebye' : 'logout'); try { divReferer(refererDomain); } catch (e) { } try { if (isNateLogin) fillPersonInfo();} catch (e) { } pageEnd('', '/');//]]>
# </script></body></html>

# %%
from bs4 import BeautifulSoup

webpage = open("C:\\Users\\jjjun_ii\\Documents\\GitHub\\LIKELION_AI\\DA_TIL\\Web\\sample1.html", 'rt').read()
bsObject = BeautifulSoup(webpage, 'html.parser')

print(bsObject)
# Out:
# <html>
# <head>
# </head>
# <body>
# <div>요기를 클릭하세요</div>
# <ul>
# <li>한빛출판네트워크</li>
# <li>비기너</li>
# <li>데이터 분석</li>
# </ul>
# </body>
# </html>

# %%
tag_div = bsObject.find("div")
print(tag_div)
# Out:
# <div>요기를 클릭하세요</div>

# %%
tag_ul = bsObject.find('ul')
print(tag_ul)
print()

tag_li = bsObject.find('li')  # 첫 번째 <li> 태그만 찾음
print(tag_li)
print()

tag_li_all = bsObject.findAll('li')  # 전체 찾기
print(tag_li_all)
# Out:
# <ul>
# <li>한빛출판네트워크</li>
# <li>비기너</li>
# <li>데이터 분석</li>
# </ul>
#
# <li>한빛출판네트워크</li>
#
# [<li>한빛출판네트워크</li>, <li>비기너</li>, <li>데이터 분석</li>]

# %% [markdown]
# ##### 1-4. 특정 태그 추출
# - id나 class를 지정해서 특정한 태그만 추출하는 방식을 사용할 수 있음
# - find() 또는 findAll()을 다음과 같은 형식으로 사용
#
# ```python
# 이름.find('태그명', {'속성명':'속성값'})
# 이름.findAll('태그명', {'속성명': '속성값'})
# ```

# %%
from bs4 import BeautifulSoup

webPage = open("C:\\Users\\jjjun_ii\\Documents\\GitHub\\LIKELION_AI\\DA_TIL\\Web\\sample2.html", 'rt', encoding="utf-8").read()
bsObject = BeautifulSoup(webPage, 'html.parser')

tag = bsObject.find('div', {'id':'myId1'})
print(tag)

tag = bsObject.find('div', {"class":"myClass1"})
print(tag)

tag = bsObject.findAll('div', {'class':'myClass1'})
print(tag)
# Out:
# <div id="myId1">아기공룡</div>
# <div class="myClass1">내 친구</div>
# [<div class="myClass1">내 친구</div>, <div class="myClass1">둘리</div>]

# %%
from bs4 import BeautifulSoup

webPage = open("C:\\Users\\jjjun_ii\\Documents\\GitHub\\LIKELION_AI\\DA_TIL\\Web\\sample2.html", 'rt', encoding="utf-8").read()
bsObject = BeautifulSoup(webPage, 'html.parser')

tag = bsObject.find('div', {'id':'myId1'})
print(tag.get_text())  # 태그 내의 내용은 get_text()

tag = bsObject.find('div', {"class":"myClass1"})
print(tag.get_text())

tag = bsObject.findAll('div', {'class':'myClass1'})
for con in tag:
    print(con.get_text())
# Out:
# 아기공룡
# 내 친구
# 내 친구
# 둘리

# %%
ul_value = bsObject.find('ul', {"class":"myClass2"})
print(ul_value)
print()
li_list = bsObject.findAll('li', {"class":"myClass3"})
print(li_list)
# Out:
# <ul class="myClass2">
# <li>한빛아카데미</li>
# <li>한빛미디어</li>
# </ul>
#
# [<li class="myClass3">비기너</li>, <li class="myClass3">둘리</li>]

# %%
a_list = bsObject.findAll('a')
for aTag in a_list:
    print(aTag)
    print(aTag["href"])
# Out:
# <a href="www.daum.net">다음 바로가기</a>
# www.daum.net
# <a href="www.nate.com">네이트 바로가기</a>
# www.nate.com
# <a href="www.naver.com">네이버 바로가기</a>
# www.naver.com

# %%
from bs4 import BeautifulSoup

webPage = open("C:\\Users\\jjjun_ii\\Documents\\GitHub\\LIKELION_AI\\DA_TIL\\Web\\sample2.html", "rt", encoding="utf-8").read()

bsObject = BeautifulSoup(webPage, 'html.parser')

tag_li_all = bsObject.findAll('li')
for tag_li in tag_li_all:
    print(tag_li.text)
    
print()

for i in range(len(tag_li_all)):
    print(tag_li_all[i].text)
# Out:
# 한빛아카데미
# 한빛미디어
# 비기너
# 둘리
#
# 한빛아카데미
# 한빛미디어
# 비기너
# 둘리

# %% [markdown]
# ### 2. 웹 크롤링 활용

# %% [markdown]
# ##### 2-1. 네이트 사이트 정보 추출

# %%
from bs4 import BeautifulSoup
import urllib.request

nateUrl = "https://www.nate.com"
htmlObject = urllib.request.urlopen(nateUrl)
webPage = htmlObject.read()
bsObject = BeautifulSoup(webPage, 'html.parser')

tag = bsObject.find("div", {"id":"NateBi"})
print(tag, '\n')

a_tag = tag.find('a')
print(a_tag, '\n')

href = a_tag['href']
print(href, '\n')

text = a_tag.text
print(text)
# Out:
# <div class="area_bi" id="NateBi" role="banner">
# <h1 class="bi" title="네이트"><a href="//www.nate.com/?f=bi" onmousedown="nc('NBI01');">네이트</a></h1>
# </div>
#
# <a href="//www.nate.com/?f=bi" onmousedown="nc('NBI01');">네이트</a>
#
# //www.nate.com/?f=bi
#
# 네이트

# %%
from bs4 import BeautifulSoup
import urllib.request

nateUrl = "https://news.nate.com"
htmlObject = urllib.request.urlopen(nateUrl)
webPage = htmlObject.read()
bsObject = BeautifulSoup(webPage, 'html.parser')

tag = bsObject.find("div", {"class":"snbArea"})

print("## 네이트 뉴스의 메뉴 목록 ##")
li_list = tag.findAll('li')
for li in li_list:
    print(li.text, end=' ')
# Out:
# ## 네이트 뉴스의 메뉴 목록 ##
# 오늘 종합 최신뉴스 정치 경제 사회 세계 IT/과학 칼럼 포토 TV 라디오 랭킹뉴스 투데이댓글

# %% [markdown]
# [실습] 네이버 메뉴 크롤링

# %%
from bs4 import BeautifulSoup
import urllib.request

url = "https://www.naver.com/"
openUrl = urllib.request.urlopen(url)
webPage = openUrl.read()
bsObject = BeautifulSoup(webPage, 'html.parser')
li_list = bsObject.findAll('li', {"class":"shortcut_item"})
print(li_list)
for li in li_list:
    print(li.text)
    
# 동적인 부분을 이렇게 크롤링하면 값이 안 가져와짐
# chrome webdriver, selenium을 활용해서 동적 페이지 크롤링
# Out:
# []

# %% [markdown]
# ##### 2-2. 시간 간격 크롤러
# - 시간 간격을 두고 작동하는 크롤러
# - 시간에 따라 변경되는 웹 데이터: 실시간 검색어, 현재 날씨, 인기 뉴스 목록 등의 데이터를 정해진 시간마다 크롤링

# %%
import csv
import time
import datetime

csvName = "C:\\Users\\jjjun_ii\\Documents\\GitHub\\LIKELION_AI\\DA_TIL\\Web\\data\\datetime.csv"
with open(csvName,'w', newline='') as csvFp:
    csvWriter = csv.writer(csvFp)
    csvWriter.writerow(["연월일", "시분초"])
    
count = 10
while count > 0:
    count -= 1
    now = datetime.datetime.now()
    yymmdd = now.strftime("%Y-%m-%d")
    hhmmss = now.strftime("%H:%M:%S")
    time_list = [yymmdd, hhmmss]
    print(time_list)
    
    with open(csvName, 'a', newline='') as csvFp:
        csvWriter = csv.writer(csvFp)
        csvWriter.writerow(time_list)

    time.sleep(3)
# Out:
# ['2023-10-16', '13:27:07']
# ['2023-10-16', '13:27:10']
# ['2023-10-16', '13:27:13']
# ['2023-10-16', '13:27:16']
# ['2023-10-16', '13:27:19']
# ['2023-10-16', '13:27:22']
# ['2023-10-16', '13:27:25']
# ['2023-10-16', '13:27:28']
# ['2023-10-16', '13:27:31']
# ['2023-10-16', '13:27:34']

# %% [markdown]
# ##### 2-3 속초 날씨 크롤러
# - 엣지 브라우저 [네이트 날씨](https://news.nate.com/weather)
# - 지역 [강원영동]-[속초]

# %%
import csv
import time
import datetime
from bs4 import BeautifulSoup
import urllib.request

csvName = "C:\\Users\\jjjun_ii\\Documents\\GitHub\\LIKELION_AI\\DA_TIL\\Web\\data\\sokcho_weather.csv"
with open(csvName, 'w', newline='') as csvFp:
    csvWriter = csv.writer(csvFp)
    csvWriter.writerow(["연월일", "시분초", "온도", "습도", "강수량", "풍향"])

nateUrl = "https://news.nate.com/weather?areaCode=11D20401"
while True:
    htmlObject = urllib.request.urlopen(nateUrl)
    webPage = htmlObject.read()
    bsObject = BeautifulSoup(webPage, 'html.parser')
    tag = bsObject.find("div", {"class":"right_today"})
    temper = tag.find('p', {"class":"celsius"}).text
    humi = tag.find('p', {"class":"humidity"}).text
    rain = tag.find('p', {"class":"rainfall"}).text
    wind = tag.find('p', {"class":"wind"}).text
    
    now = datetime.datetime.now()
    yymmdd = now.strftime("%Y-%m-%d")
    hhmmss = now.strftime("%H:%M:%S")
    
    weather_list = [yymmdd, hhmmss, temper, humi, rain, wind]
    with open(csvName, 'a', newline='') as csvFp:
        csvWriter = csv.writer(csvFp)
        csvWriter.writerow(weather_list)
        
    time.sleep(30)  # 시간 조절
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\jjjun_ii\Documents\GitHub\LIKELION_AI\DA_TIL\Web\web.ipynb Cell 27 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/jjjun_ii/Documents/GitHub/LIKELION_AI/DA_TIL/Web/web.ipynb#X40sZmlsZQ%3D%3D?line=28'>29</a>     csvWriter = csv.writer(csvFp)
#      <a href='vscode-notebook-cell:/c%3A/Users/jjjun_ii/Documents/GitHub/LIKELION_AI/DA_TIL/Web/web.ipynb#X40sZmlsZQ%3D%3D?line=29'>30</a>     csvWriter.writerow(weather_list)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/jjjun_ii/Documents/GitHub/LIKELION_AI/DA_TIL/Web/web.ipynb#X40sZmlsZQ%3D%3D?line=31'>32</a> time.sleep(30)  # 시간 조절
#
# KeyboardInterrupt:

# %% [markdown]
# ### 3. 웹 크롤링 실전

# %% [markdown]
# ##### 3-1. 한국소설 순위별 정보 추출
# - [YES24](https://www.yes24.com)에서 한국소설의 도서명, 가격, 저자를 순위대로 추출

# %%
import csv
from bs4 import BeautifulSoup
import urllib.request

csv_name = "C:\\Users\\jjjun_ii\\Documents\\GitHub\\LIKELION_AI\\DA_TIL\\Web\\data\\yes24_ranking.csv"
with open(csv_name, 'w', newline = '') as csvFp:
    csv_writer = csv.writer(csvFp)
    csv_writer.writerow(["도서명", "저자", "출판사", "출간일", "가격"])
    
url = "https://www.yes24.com/24/Category/Display/001001046001?ParamSortTp=05&PageNumber=1"
request = urllib.request.urlopen(url)
webpage = request.read()
bs4 = BeautifulSoup(webpage, 'html.parser')

div_list = bs4.findAll("div", {"class":"cCont_goodsSet"})

for div in div_list:
    name = div.find('div', {"class":"goods_name"}).find('a').text
    print(name, end=' ')
    auth = div.find('span', {"class":"goods_auth"}).find('a').text
    print(auth, end=' ')
    price = div.find('em', {"class":"yes_b"}).text
    print(price, end=' ')
    pub = div.find('span', {"class":"goods_pub"}).text
    print(pub, end=' ')
    date = div.find('span', {"class":"goods_date"}).text
    print(date, end=' ')
    print()
    
    with open(csv_name, 'a', newline='') as csvFp:
        csv_writer = csv.writer(csvFp)
        csv_writer.writerow([name, auth, pub, date, price])
# Out:
# 불편한 편의점 김호연 12,600 나무옆의자 2021년 04월
# 아버지의 해방일지 정지아 13,500 창비 2022년 09월
# 불편한 편의점 2 김호연 12,600 나무옆의자 2022년 08월
# 메리골드 마음 세탁소 윤정은 13,500 북로망스 2023년 03월
# 하얼빈 김훈 14,400 문학동네 2022년 08월
# 모순 양귀자 11,700 쓰다 2013년 04월
# 아주 희미한 빛으로도 최은영 15,120 문학동네 2023년 08월
# 달러구트 꿈 백화점  이미예 12,420 팩토리나인 2020년 07월
# 작별인사 김영하 12,600 복복서가 2022년 09월
# 어서 오세요, 휴남동 서점입니다 황보름 13,500 클레이하우스 2022년 01월
# 이토록 평범한 미래 김연수 12,600 문학동네 2022년 10월
# 구의 증명 최진영 10,800 은행나무 2023년 04월
# 구의 증명 최진영 7,200 은행나무 2015년 03월
# 달러구트 꿈 백화점 2 (레인보우 에디션) 이미예 12,420 팩토리나인 2021년 07월
# 파견자들 김초엽 17,100 퍼블리온 2023년 10월
# 비가 오면 열리는 상점 유영광 15,120 클레이하우스 2023년 06월
# 칵테일, 러브, 좀비 조예은 9,000 안전가옥 2020년 04월
# 지구 끝의 온실 김초엽 13,500 자이언트북스 2021년 08월
# 밝은 밤 최은영 13,950 문학동네 2021년 07월
# 2023 제14회 젊은작가상 수상작품집 이미상 6,930 문학동네 2023년 04월

# %% [markdown]
# [함수로 재작성]

# %%
from bs4 import BeautifulSoup
import urllib.request

# 한 권의 책 정보가 들어있는 <div class="goods.info"의 내용을 파라미터로 받음
def get_book_info(book_tag):
    name = book_tag.find("div", {"class":"goods_name"})
    book_name = name.find('a').text
    auth = book_tag.find("span", {"class":"goods_auth"})
    book_auth = auth.find('a').text
    book_pub = book_tag.find("span", {"class":"goods_pub"}).text
    book_price = book_tag.find("em", {"class":"yes_b"}).text
    book_date = book_tag.find("span", {"class":"goods_date"}).text
    
    return [book_name, book_auth, book_pub, book_date, book_price]

# %%
bookUrl = "https://www.yes24.com/24/Category/Display/001001046001?ParamSortTp=05&PageNumber=1"

htmlObject = urllib.request.urlopen(bookUrl)
webPage = htmlObject.read()
bsObject = BeautifulSoup(webPage, 'html.parser')
tag = bsObject.find('ul', {"class":"clearfix"})
all_books = tag.findAll("div", {"class":"goods_info"})

for book in all_books:
    print(get_book_info(book))
# Out:
# ['불편한 편의점', '김호연', '나무옆의자', '2021년 04월', '12,600']
# ['아버지의 해방일지', '정지아', '창비', '2022년 09월', '13,500']
# ['불편한 편의점 2', '김호연', '나무옆의자', '2022년 08월', '12,600']
# ['메리골드 마음 세탁소', '윤정은', '북로망스', '2023년 03월', '13,500']
# ['하얼빈', '김훈', '문학동네', '2022년 08월', '14,400']
# ['모순', '양귀자', '쓰다', '2013년 04월', '11,700']
# ['아주 희미한 빛으로도', '최은영', '문학동네', '2023년 08월', '15,120']
# ['달러구트 꿈 백화점 ', '이미예', '팩토리나인', '2020년 07월', '12,420']
# ['작별인사', '김영하', '복복서가', '2022년 09월', '12,600']
# ['어서 오세요, 휴남동 서점입니다', '황보름', '클레이하우스', '2022년 01월', '13,500']
# ['이토록 평범한 미래', '김연수', '문학동네', '2022년 10월', '12,600']
# ['구의 증명', '최진영', '은행나무', '2023년 04월', '10,800']
# ['구의 증명', '최진영', '은행나무', '2015년 03월', '7,200']
# ['달러구트 꿈 백화점 2 (레인보우 에디션)', '이미예', '팩토리나인', '2021년 07월', '12,420']
# ['파견자들', '김초엽', '퍼블리온', '2023년 10월', '17,100']
# ['비가 오면 열리는 상점', '유영광', '클레이하우스', '2023년 06월', '15,120']
# ['칵테일, 러브, 좀비', '조예은', '안전가옥', '2020년 04월', '9,000']
# ['지구 끝의 온실', '김초엽', '자이언트북스', '2021년 08월', '13,500']
# ['밝은 밤', '최은영', '문학동네', '2021년 07월', '13,950']
# ['2023 제14회 젊은작가상 수상작품집', '이미상', '문학동네', '2023년 04월', '6,930']

# %% [markdown]
# [20권의 총 금액 출력]

# %%
from bs4 import BeautifulSoup
import urllib.request

# 한 권의 책 정보가 들어있는 <div class="goods.info"의 내용을 파라미터로 받음
def get_book_price(book_tag):
    book_price = book_tag.find("em", {"class":"yes_b"}).text
    
    return int(book_price.replace(",", ""))

# %%
bookUrl = "https://www.yes24.com/24/Category/Display/001001046001?ParamSortTp=05&PageNumber=1"

htmlObject = urllib.request.urlopen(bookUrl)
webPage = htmlObject.read()
bsObject = BeautifulSoup(webPage, 'html.parser')
tag = bsObject.find('ul', {"class":"clearfix"})
all_books = tag.findAll("div", {"class":"goods_info"})

total_price = 0
for book in all_books:
    total_price += get_book_price(book)
    
print("총액 => " + "{:,}".format(total_price) + " 원")
# Out:
# 총액 => 250,560 원

# %% [markdown]
# ##### 3-2. 소설 목록의 마지막 페이지까지 모든 내용 출력

# %%
from bs4 import BeautifulSoup
import urllib.request

# 한 권의 책 정보가 들어있는 <div class="goods.info"의 내용을 파라미터로 받음
def get_book_info(book_tag):
    name = book_tag.find("div", {"class":"goods_name"})
    book_name = name.find('a').text
    auth = book_tag.find("span", {"class":"goods_auth"})
    book_auth = auth.find('a').text
    book_pub = book_tag.find("span", {"class":"goods_pub"}).text
    book_price = book_tag.find("em", {"class":"yes_b"}).text
    book_date = book_tag.find("span", {"class":"goods_date"}).text
    
    return [book_name, book_auth, book_pub, book_date, book_price]

# %%
page = 1

while True:
    
    try:
        bookUrl = "https://www.yes24.com/24/Category/Display/001001046001?ParamSortTp=05&PageNumber={0}".format(page)

        htmlObject = urllib.request.urlopen(bookUrl)
        webPage = htmlObject.read()
        bsObject = BeautifulSoup(webPage, 'html.parser')
        tag = bsObject.find('ul', {"class":"clearfix"})
        all_books = tag.findAll("div", {"class":"goods_info"})

        for book in all_books:
            print(get_book_info(book))
        
        page += 1
    except:
        break
# Out:
# ['불편한 편의점', '김호연', '나무옆의자', '2021년 04월', '12,600']
# ['아버지의 해방일지', '정지아', '창비', '2022년 09월', '13,500']
# ['불편한 편의점 2', '김호연', '나무옆의자', '2022년 08월', '12,600']
# ['메리골드 마음 세탁소', '윤정은', '북로망스', '2023년 03월', '13,500']
# ['하얼빈', '김훈', '문학동네', '2022년 08월', '14,400']
# ['모순', '양귀자', '쓰다', '2013년 04월', '11,700']
# ['아주 희미한 빛으로도', '최은영', '문학동네', '2023년 08월', '15,120']
# ['달러구트 꿈 백화점 ', '이미예', '팩토리나인', '2020년 07월', '12,420']
# ['작별인사', '김영하', '복복서가', '2022년 09월', '12,600']
# ['어서 오세요, 휴남동 서점입니다', '황보름', '클레이하우스', '2022년 01월', '13,500']
# ['이토록 평범한 미래', '김연수', '문학동네', '2022년 10월', '12,600']
# ['구의 증명', '최진영', '은행나무', '2023년 04월', '10,800']
# ['구의 증명', '최진영', '은행나무', '2015년 03월', '7,200']
# ['달러구트 꿈 백화점 2 (레인보우 에디션)', '이미예', '팩토리나인', '2021년 07월', '12,420']
# ['파견자들', '김초엽', '퍼블리온', '2023년 10월', '17,100']
# ['비가 오면 열리는 상점', '유영광', '클레이하우스', '2023년 06월', '15,120']
# ['칵테일, 러브, 좀비', '조예은', '안전가옥', '2020년 04월', '9,000']
# ['지구 끝의 온실', '김초엽', '자이언트북스', '2021년 08월', '13,500']
# ['밝은 밤', '최은영', '문학동네', '2021년 07월', '13,950']
# ['2023 제14회 젊은작가상 수상작품집', '이미상', '문학동네', '2023년 04월', '6,930']
# ['회색 인간', '김동식', '요다', '2017년 12월', '11,700']
# ['우리가 빛의 속도로 갈 수 없다면', '김초엽', '허블', '2019년 06월', '12,600']
# ['너무나 많은 여름이', '김연수', '레제', '2023년 06월', '14,400']
# ['고래', '천명관', '문학동네', '2004년 12월', '13,500']
# ['훌훌', '문경민', '문학동네', '2022년 02월', '11,250']
# ['[예스리커버] 가녀장의 시대', '이슬아', '이야기장수', '2022년 10월', '13,500']
# ['소년이 온다', '한강', '창비', '2014년 05월', '13,500']
# ['천 개의 파랑', '천선란', '허블', '2020년 08월', '12,600']
# ['풍수전쟁', '김진명', '이타북스', '2023년 05월', '15,120']
# ['단 한 사람', '최진영', '한겨레출판', '2023년 09월', '13,500']
# ['사랑의 이해', '이혁진', '민음사', '2019년 04월', '13,500']
# ['난장이가 쏘아올린 작은 공', '조세희', '이성과 힘', '2000년 07월', '11,700']
# ['한국단편소설 40', '성낙수', '리베르', '2012년 11월', '15,120']
# ['눈부신 안부', '백수린', '문학동네', '2023년 05월', '14,400']
# ['아몬드', '손원평', '창비', '2017년 03월', '12,600']
# ['파과', '구병모', '위즈덤하우스', '2018년 04월', '12,600']
# ['달의 아이', '최윤석', '포레스트북스', '2023년 09월', '15,300']
# ['나는 소망한다 내게 금지된 것을', '양귀자', '쓰다', '2019년 04월', '13,500']
# ['푸틴을 죽이는 완벽한 방법', '김진명', '이타북스', '2023년 09월', '16,920']
# ['아가미', '구병모', '위즈덤하우스', '2018년 03월', '11,700']
# ['채식주의자', '한강', '창비', '2022년 03월', '13,500']
# ['종의 기원', '정유정', '은행나무', '2016년 05월', '11,700']
# ['홍학의 자리', '정해연', '엘릭시르', '2021년 07월', '12,600']
# ['크리스마스 타일', '김금희', '창비', '2022년 11월', '13,500']
# ['[최근담] 가꾸는 이의 즐거움', '이유리', '예스이십사', '2022년 04월', '0']
# ['고래 ', '천명관', '문학동네', '2023년 05월', '14,850']
# ['시선으로부터,', '정세랑', '문학동네', '2020년 06월', '12,600']
# ['지구에서 한아뿐', '정세랑', '난다', '2019년 07월', '11,700']
# ['트로피컬 나이트', '조예은', '한겨레출판', '2022년 08월', '13,500']
# ['연수', '장류진', '창비', '2023년 06월', '15,120']
# ['쇼코의 미소', '최은영', '문학동네', '2016년 07월', '13,050']
# ['사서함 110호의 우편물', '이도우', '수박설탕', '2022년 07월', '15,300']
# ['환상서점 ', '소서림', '해피북스투유', '2023년 02월', '13,950']
# ['바깥은 여름', '김애란', '문학동네', '2017년 06월', '13,050']
# ['재벌집 막내아들 1', '산경', '테라코타', '2022년 11월', '15,300']
# ['저주토끼 ', '정보라', '래빗홀', '2023년 04월', '14,220']
# ['테스터', '이희영', '허블', '2022년 11월', '12,600']
# ['유괴의 날', '정해연', '시공사', '2019년 07월', '15,300']
# ['요괴어사', '설민석', '단꿈아이', '2023년 04월', '16,200']
# ['살인자의 기억법', '김영하', '복복서가', '2020년 08월', '9,000']
# ['해가 지는 곳으로', '최진영', '민음사', '2017년 06월', '12,600']
# ['홈 스위트 홈', '최진영', '문학사상', '2023년 02월', '13,950']
# ['위저드 베이커리', '구병모', '창비', '2022년 03월', '12,600']
# ['튜브', '손원평', '창비', '2022년 07월', '13,500']
# ['피프티 피플', '정세랑', '창비', '2021년 08월', '12,600']
# ['재벌집 막내아들 2', '산경', '테라코타', '2022년 11월', '15,300']
# ['아몬드', '손원평', '다즐링', '2023년 07월', '15,120']
# ['망원동 브라더스', '김호연', '나무옆의자', '2013년 07월', '11,700']
# ['이끼숲', '천선란', '자이언트북스', '2023년 05월', '14,220']
# ['죽이고 싶은 아이', '이꽃님', '우리학교', '2021년 10월', '12,600']
# ['여름의 빌라', '백수린', '문학동네', '2020년 07월', '13,320']
# ['재벌집 막내아들 3', '산경', '테라코타', '2022년 11월', '15,300']
# ['각각의 계절', '권여선', '문학동네', '2023년 05월', '13,500']
# ['재벌집 막내아들 5', '산경', '테라코타', '2022년 11월', '15,300']
# ['재벌집 막내아들 4', '산경', '테라코타', '2022년 11월', '15,300']
# ['검은 꽃', '김영하', '복복서가', '2020년 07월', '9,900']
# ['마당이 있는 집', '김진영', '엘릭시르', '2018년 04월', '12,420']
# ['랑과 나의 사막', '천선란', '현대문학', '2022년 10월', '11,700']
# ['전지적 독자 시점 PART 1 - 01', '싱숑', '비채', '2022년 01월', '12,150']
# ['파쇄', '구병모', '위즈덤하우스', '2023년 03월', '11,700']
# ['전지적 독자 시점 PART 1 - 02', '싱숑', '비채', '2022년 01월', '12,150']
# ['그 많던 싱아는 누가 다 먹었을까', '박완서', '웅진지식하우스', '2021년 01월', '11,700']
# ['완전한 행복', '정유정', '은행나무', '2021년 06월', '14,220']
# ['전지적 독자 시점 PART 1 - 07', '싱숑', '비채', '2022년 01월', '12,150']
# ['전지적 독자 시점 PART 1 - 03', '싱숑', '비채', '2022년 01월', '12,150']
# ['책들의 부엌', '김지혜', '팩토리나인', '2022년 05월', '13,050']
# ['전지적 독자 시점 PART 1 - 08', '싱숑', '비채', '2022년 01월', '12,150']
# ['빨치산의 딸 1', '정지아', '필맥', '2005년 05월', '8,550']
# ['작별하지 않는다', '한강', '문학동네', '2021년 09월', '12,600']
# ['[최근담] 그래머블 제로 Grammable zero', '박서련', '예스이십사', '2022년 05월', '0']
# ['전지적 독자 시점 PART 1 - 06', '싱숑', '비채', '2022년 01월', '12,150']
# ['빨치산의 딸 2', '정지아', '필맥', '2005년 05월', '8,550']
# ['소설 보다 : 가을 2023', '김지연', '문학과지성사', '2023년 09월', '3,150']
# ['연남동 빙굴빙굴 빨래방', '김지윤', '팩토리나인', '2023년 08월', '15,120']
# ['[예스리커버] 천 개의 파랑', '천선란', '허블', '2022년 11월', '12,600']
# ['전지적 독자 시점 PART 1 - 04', '싱숑', '비채', '2022년 01월', '12,150']
# ['아홉살 인생', '위기철', '현북스', '2020년 05월', '10,800']
# ['탱크', '김희재', '한겨레출판', '2023년 07월', '13,500']
# ['전지적 독자 시점 PART 1 - 05', '싱숑', '비채', '2022년 01월', '12,150']
# ['범도 1', '방현석', '문학동네', '2023년 06월', '18,000']
# ['내게 무해한 사람', '최은영', '문학동네', '2018년 06월', '13,050']
# ['땀 흘리는 소설', '김혜진', '창비교육', '2019년 03월', '13,500']
# ['칼의 노래', '김훈', '문학동네', '2014년 01월', '13,500']
# ['방금 떠나온 세계', '김초엽', '한겨레출판', '2021년 10월', '13,500']
# ['젓가락 달인', '유타루', '바람의아이들', '2014년 06월', '11,700']
# ['고통에 관하여', '정보라', '다산책방', '2023년 08월', '16,200']
# ['범도 2', '방현석', '문학동네', '2023년 06월', '18,000']
# ['순이 삼촌', '현기영', '창비', '2015년 03월', '14,400']
# ['소설 보다 : 여름 2023', '공현진', '문학과지성사', '2023년 06월', '3,150']
# ['한국고전소설 40', '권정현', '리베르', '2013년 01월', '15,120']
# ['소설 보다 : 봄 2023', '강보라', '문학과지성사', '2023년 03월', '3,150']
# ['원미동 사람들', '양귀자', '쓰다', '2012년 12월', '11,700']
# ['세계를 건너 너에게 갈게', '이꽃님', '문학동네', '2020년 11월', '12,600']
# ['새의 선물', '은희경', '문학동네', '2022년 06월', '14,400']
# ['날씨가 좋으면 찾아가겠어요', '이도우', '시공사', '2018년 07월', '12,420']
# ['아홉수 가위', '범유진', '안전가옥', '2021년 10월', '9,000']
# ['인생 박물관', '김동식', '요다', '2023년 03월', '13,500']
# ['나인', '천선란', '창비', '2021년 11월', '13,500']
# ['나주에 대하여', '김화진', '문학동네', '2022년 10월', '13,500']
# ['무진기행', '김승옥', '민음사', '2007년 08월', '9,000']
# ['애쓰지 않아도', '최은영', '마음산책', '2022년 04월', '13,050']
# ['돌이킬 수 있는', '문목하', '아작', '2018년 12월', '13,320']
# ['2022 제13회 젊은작가상 수상작품집', '임솔아', '문학동네', '2022년 04월', '12,600']
# ['2022 김승옥문학상 수상작품집', '편혜영', '문학동네', '2022년 09월', '9,000']
# ['페퍼민트', '백온유', '창비', '2022년 07월', '12,600']
# ['7년의 밤', '정유정', '은행나무', '2011년 03월', '13,050']
# ['유령의 마음으로', '임선우', '민음사', '2022년 03월', '11,700']
# ['호텔 이야기', '임경선', '토스트', '2022년 11월', '13,500']
# ['페인트', '이희영', '창비', '2019년 11월', '12,600']
# ['한국단편소설 70', '박완서', '리베르', '2013년 01월', '15,120']
# ['하쿠다 사진관 ', '허태연', '놀', '2022년 07월', '13,950']
# ['어느 날 내가 죽었습니다', '이경혜', '바람의아이들', '2004년 04월', '12,600']
# ['비행운', '김애란', '문학과지성사', '2012년 07월', '10,800']
# ['느티나무 수호대', '김중미', '돌베개', '2023년 03월', '12,600']
# ['저만치 혼자서', '김훈', '문학동네', '2022년 06월', '13,500']
# ['경우 없는 세계', '백온유', '창비', '2023년 03월', '13,500']
# ['알래스카 한의원', '이소영', '사계절', '2023년 03월', '13,500']
# ['내게 남은 사랑을 드릴게요', '이유리', '자이언트북스', '2023년 01월', '14,220']
# ['2023 김승옥문학상 수상작품집', '권여선', '문학동네', '2023년 10월', '10,800']
# ['클로버', '나혜림', '창비', '2022년 09월', '12,600']
# ['[예스리커버] 트로피컬 나이트', '조예은', '한겨레출판', '2023년 08월', '13,500']
# ['제주도우다 세트', '현기영', '창비', '2023년 07월', '45,900']
# ['급류', '정대건', '민음사', '2022년 12월', '12,600']
# ['모두의 연수', '김려령', '비룡소', '2023년 05월', '13,500']
# ['테디베어는 죽지 않아', '조예은', '안전가옥', '2023년 06월', '15,030']
# ['날개', '이상', '문학과지성사', '2005년 04월', '12,600']
# ['우리가 겨울을 지나온 방식', '문미순', '나무옆의자', '2023년 05월', '12,600']
# ['기억을 넘어 너에게 갈게', '양은애', '토마토출판사', '2023년 01월', '11,700']
# ['재수사 2', '장강명', '은행나무', '2022년 08월', '14,400']
# ['대도시의 사랑법', '박상영', '창비', '2019년 07월', '12,600']
# ['너는, 어느 계절에 죽고 싶어', '홍선기', '모모', '2023년 06월', '15,120']
# ['밸런스 게임', '김동식', '요다', '2021년 03월', '11,700']
# ['수상한 초콜릿 가게', '김예은', '서랍의날씨', '2022년 10월', '12,150']
# ['두근두근 내 인생', '김애란', '창비', '2011년 06월', '12,600']
# ['사랑과 혁명 1', '김탁환', '해냄', '2023년 09월', '16,920']
# ['남한산성', '김훈', '학고재', '2017년 07월', '14,400']
# ['재수사 1', '장강명', '은행나무', '2022년 08월', '14,400']
# ['이상 소설 전집', '이상', '민음사', '2012년 11월', '11,700']
# ['고구려 7', '김진명', '이타북스', '2021년 06월', '14,220']
# ['있을 법한 모든 것', '구병모', '문학동네', '2023년 07월', '13,500']
# ['광장/구운몽', '최인훈', '문학과지성사', '2014년 12월', '10,800']
# ['경청  ', '김혜진', '민음사', '2022년 10월', '13,500']
# ['귤의 맛', '조남주', '문학동네', '2020년 05월', '11,250']
# ['인어 사냥 ', '차인표', '해결책', '2022년 10월', '13,500']
# ['일의 기쁨과 슬픔', '장류진', '창비', '2019년 10월', '12,600']
# ['내가 되는 꿈', '최진영', '현대문학', '2021년 02월', '12,600']
# ['숨 쉬는 소설', '최진영', '창비교육', '2021년 08월', '14,400']
# ['나의 아름다운 정원', '심윤경', '한겨레출판', '2013년 11월', '9,900']
# ['눈물을 마시는 새 특별판 세트 ', '이영도', '황금가지', '2023년 05월', '90,000']
# ['세상에서 가장 약한 요괴', '김동식', '요다', '2017년 12월', '11,700']
# ['소설 보다 : 겨울 2022', '김채원', '문학과지성사', '2022년 12월', '3,150']
# ['손 흔드는 소설', '최은영', '창비교육', '2022년 12월', '15,300']
# ['나의 아름다운 날들', '정지아', '은행나무', '2023년 02월', '14,400']
# ['알로하, 나의 엄마들', '이금이', '창비', '2020년 03월', '13,320']
# ['친밀한 이방인', '정한아', '문학동네', '2017년 10월', '11,700']
# ['까칠한 재석이가 사라졌다', '고정욱', '애플북스', '2022년 04월', '10,800']
# ['행성어 서점', '김초엽', '마음산책', '2021년 11월', '13,050']
# ['작별 곁에서', '신경숙', '창비', '2023년 05월', '13,500']
# ['설이', '심윤경', '한겨레출판', '2019년 01월', '11,700']
# ['중고생이 꼭 읽어야 할 한국단편소설 45', '오대교', '생각뿔', '2019년 08월', '19,800']
# ['나목', '박완서', '세계사', '2012년 01월', '12,600']
# ['당신이 보고 싶어하는 세상', '장강명', '문학동네', '2023년 07월', '15,300']
# ['사랑과 혁명 2', '김탁환', '해냄', '2023년 09월', '16,920']
# ['사랑과 혁명 3', '김탁환', '해냄', '2023년 09월', '16,920']
# ['어떤 진심 ', '안보윤', '현대문학', '2022년 12월', '13,500']
# ['운수 좋은 날', '현진건', '사피엔스21', '2012년 02월', '6,300']
# ['2023 제6회 한국과학문학상 수상작품집', '한이솔', '허블', '2023년 05월', '6,930']
# ['브로콜리 펀치', '이유리', '문학과지성사', '2021년 10월', '12,600']
# ['13일의 김남우', '김동식', '요다', '2017년 12월', '11,700']
# ['구운몽', '김만중', '민음사', '2003년 01월', '7,200']
# ['나는 나를 파괴할 권리가 있다', '김영하', '복복서가', '2022년 05월', '10,350']
# ['가슴 뛰는 소설 : 사랑이 움직이는 순간', '박상영', '창비교육', '2020년 08월', '14,400']
# ['나나', '이희영', '창비', '2021년 10월', '11,700']
# ['얼티밋 워리어', '찰리와 하이파이브', '삼일인포마인', '2023년 03월', '22,000']
# ['1차원이 되고 싶어', '박상영', '문학동네', '2021년 10월', '13,320']
# ['아몬드', '손원평', '창비', '2022년 05월', '10,800']
# ['저주토끼', '정보라', '아작', '2022년 04월', '13,320']
# ['칼의 노래', '김훈', '문학동네', '2012년 01월', '12,600']
# ['자본주의의 적', '정지아', '창비', '2021년 04월', '12,600']
# ['청년 주부 구운몽', '강선우', '고즈넉이엔티', '2023년 02월', '13,500']

# %% [markdown]
# ##### [실습] 네이트 실시간 뉴스 크롤링

# %%
from bs4 import BeautifulSoup
import urllib.request
import time

def crawler(url):
    count = 1
    while True:
        htmlObject = urllib.request.urlopen(url)
        webPage = htmlObject.read()
        bsObject = BeautifulSoup(webPage, 'html.parser')
        
        news_div_list = bsObject.findAll("div", {"class":"mlt01"})
        print(f"{count}회 출력입니다")
        for news in news_div_list:
            title = news.find("h2", {"class":"tit"}).text
            link = news.find("a", {"class":"lt1"})["href"]
            pub = news.find("span", {"class":"medium"}).text.split('\t')[0]
            date = news.find("span", {"class":"medium"}).find("em").text
            print([title, link, pub, date])
            
        count += 1
        print()
        time.sleep(60)

# %%
url = "https://news.nate.com/recent?mid=n0100"
crawler(url)
# Out:
# 1회 출력입니다
# ['이재명 부부 법카 제보자 공개 회견 "명백한 범죄…진실 말해 편해지길"', '//news.nate.com/view/20231018n13355?mid=n0100', '조선일보', '10-18 11:31']
# ['결혼·취업 못한 좌절 청년 포섭하는 하마스…분노를 노린다 [노석조의 외설]', '//news.nate.com/view/20231018n00238?mid=n0100', '조선일보', '10-18 11:30']
# ['수지·양세종, 올 블랙 하트 [SE★포토]', '//news.nate.com/view/20231018n14776?mid=n0100', '서울경제', '10-18 11:30']
# ["[포토]'이두나!' 수지, 은퇴한 아이돌 이두나로 변신", '//news.nate.com/view/20231018n14775?mid=n0100', '조이뉴스24', '10-18 11:30']
# ['국감서 업무현황보고하는 부산대 차정인총장', '//news.nate.com/view/20231018n14774?mid=n0100', '연합뉴스', '10-18 11:30']
# ['\'물오른 득점력\' 황희찬 "팀에 집중하면 개인 기록도 따라올 것"', '//news.nate.com/view/20231018n14773?mid=n0100', '쿠키뉴스', '10-18 11:30']
# ["베스핀글로벌, '韓-중동 디지털 이노베이션 포럼 2023' 성료", '//news.nate.com/view/20231018n14772?mid=n0100', '이데일리', '10-18 11:30']
# ['국감서 업무현황보고하는 부산대 차정인총장', '//news.nate.com/view/20231018n14771?mid=n0100', '연합뉴스', '10-18 11:30']
# ['수지·양세종, 비주얼 커플 [SE★포토]', '//news.nate.com/view/20231018n14770?mid=n0100', '서울경제', '10-18 11:30']
# ['[영상] "이 사람 보셨으면"…한손에 아이 안고 오토바이로 질주', '//news.nate.com/view/20231018n14769?mid=n0100', '매일경제', '10-18 11:30']
# ['국감서 업무현황보고하는 경상국립대 권순기총장', '//news.nate.com/view/20231018n14768?mid=n0100', '연합뉴스', '10-18 11:30']
# ['코스피, 2560선서 등락…외인 이틀 연속 사자', '//news.nate.com/view/20231018n14767?mid=n0100', '이데일리', '10-18 11:30']
# ['체불임금 눈덩이 대유위니아, 개별 임금·퇴직금 소송 이어져', '//news.nate.com/view/20231018n14766?mid=n0100', '연합뉴스', '10-18 11:30']
# ['경기도교육청, 2025년까지 초등학교 과밀학급 없앤다', '//news.nate.com/view/20231018n14765?mid=n0100', '이데일리', '10-18 11:30']
# ["양세종 '웹툰 속 원준 그 자체'[엑's HD포토]", '//news.nate.com/view/20231018n14764?mid=n0100', '엑스포츠뉴스', '10-18 11:30']
# ['\'이두나!\' 수지 "미쓰에이 아닌 드림스윗으로 K콘 무대…묘한 기시감"', '//news.nate.com/view/20231018n14763?mid=n0100', '일간스포츠', '10-18 11:30']
# ["[포토]'이두나!' 수지, 심쿵 엔딩포즈", '//news.nate.com/view/20231018n14762?mid=n0100', '조이뉴스24', '10-18 11:30']
# ['40대 성범죄자 괴산서 전자발찌 훼손하고 도주…공개 수배', '//news.nate.com/view/20231018n14761?mid=n0100', '연합뉴스', '10-18 11:30']
# ["[포토] 수지, '아름다운 미모에 시선강탈'", '//news.nate.com/view/20231018n14760?mid=n0100', '한국경제', '10-18 11:30']
# ["5시리즈 말고도 더 있었다…BMW레이디스챔피언십, 'XM레이블레드''i7 M70xDrive' 공개", '//news.nate.com/view/20231018n14759?mid=n0100', 'OSEN', '10-18 11:30']
#
# 2회 출력입니다
# ['킹덤 아서, 내가 바로 비의 왕', '//news.nate.com/view/20231018n14942?mid=n0100', '뉴스1', '10-18 11:32']
# ['킹덤 아서, 수줍게 손하트', '//news.nate.com/view/20231018n14941?mid=n0100', '뉴스1', '10-18 11:32']
# ["'의대정원 확대 추진'에 포항시 연구중심의대 설립 탄력받나", '//news.nate.com/view/20231018n14940?mid=n0100', '뉴스1', '10-18 11:32']
# ['[국감]질의하는 정경희 의원', '//news.nate.com/view/20231018n14939?mid=n0100', '뉴스1', '10-18 11:32']
# ['[제주시 소식] 시니어 친화형 국민체육센터 건립 추진', '//news.nate.com/view/20231018n14938?mid=n0100', '뉴스1', '10-18 11:32']
# ["다국적 제약사들, 암세포 증식 'PRMT5' 억제제 개발 경쟁 치열", '//news.nate.com/view/20231018n14937?mid=n0100', '뉴스1', '10-18 11:32']
# ['국민첫사랑 수지', '//news.nate.com/view/20231018n14936?mid=n0100', '뉴스1', '10-18 11:32']
# ["사랑 가득한 '이두나1' 주역들", '//news.nate.com/view/20231018n14935?mid=n0100', '뉴스1', '10-18 11:32']
# ['3M 접착제로 붙였는데 피해 7억?…검찰로 간 흰고래 방류 시위', '//news.nate.com/view/20231018n07814?mid=n0100', 'SBS', '10-18 11:32']
# ['200일 대장정서 나온 KBO리그 진기록…롯데 팀 노히트노런 으뜸', '//news.nate.com/view/20231018n14933?mid=n0100', 'SBS', '10-18 11:32']
# ["'고사상 돼지머리'에 5만원 꽂은 농협 조합장…벌금 50만원", '//news.nate.com/view/20231018n14932?mid=n0100', '뉴스1', '10-18 11:32']
# ['"이지혜 남편 살 너무 빠져"…\'위약금無\' 다이어트 성공 근황 화제 [엑\'s 이슈]', '//news.nate.com/view/20231018n13734?mid=n0100', '엑스포츠뉴스', '10-18 11:32']
# ['수지, 드림스윗 이두나', '//news.nate.com/view/20231018n14930?mid=n0100', '뉴스1', '10-18 11:32']
# ['"피임 기구 사이즈 안 맞아 사용 NO"→장모 카드 사용…\'경악\' (고딩엄빠4)', '//news.nate.com/view/20231018n14929?mid=n0100', '엑스포츠뉴스', '10-18 11:32']
# ['우크라戰 중재 자처 튀르키예, 이-팔 전쟁도 중재 나서', '//news.nate.com/view/20231018n14863?mid=n0100', '조선비즈', '10-18 11:32']
# ['\'경희대생\' 장현성 子 준우, 동생 과외 후 성적 향상 "뭘 해도 되는 집안"', '//news.nate.com/view/20231018n12205?mid=n0100', '엑스포츠뉴스', '10-18 11:32']
# ['킹덤 아서, CD로 가리는 작은 얼굴[포토엔HD]', '//news.nate.com/view/20231018n14926?mid=n0100', '뉴스엔', '10-18 11:32']
# ['[전문] 아이유 뿔났다 "에티켓 위반 시 \'유애나\' 박탈"', '//news.nate.com/view/20231018n14149?mid=n0100', '스포츠경향', '10-18 11:32']
# ['민주당, 수원지검 2차장 비리 의혹으로 공수처 고발키로', '//news.nate.com/view/20231018n14924?mid=n0100', 'SBS', '10-18 11:32']
# ["넷플릭스 시리즈 '이두나!' 주역들", '//news.nate.com/view/20231018n14923?mid=n0100', '스포츠한국', '10-18 11:32']
