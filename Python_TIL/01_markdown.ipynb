# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# # markdown

# %% [markdown]
# # markdown

# %% [markdown]
# ## 1. 제목 (Header)

# %% [markdown]
# # 제목 1
# ## 제목 2
# ### 제목 3
# #### 제목 4
# ##### 제목 5

# %% [markdown]
# # 예제

# %% [markdown]
# ## 2. 목록
# - 순서가 없는 목록

# %% [markdown]
# - 목록 1
# - 목록 2
# - 목록 3

# %% [markdown]
# - 목록 1
#     - 목록 1-1
#         - 목록 1-2
#             - 목록 1-3
#                 - 목록 1-4

# %% [markdown]
# - 순서가 있는 목록

# %% [markdown]
# 1. 목록 첫 번째
# 2. 목록 두 번째
# 3. 목록 세 번째

# %% [markdown]
# 1. 목록 첫 번째
#     2. 목록 두 번째
#         3. 목록 세 번째

# %% [markdown]
# ## 3. 강조

# %% [markdown]
# - 이탤릭체

# %% [markdown]
# *이탤릭체*
# _이탤릭체_

# %% [markdown]
# - 굵은 글씨 (볼드체)

# %% [markdown]
# **굵은 글씨**
# __굵은 글씨__

# %% [markdown]
# ## 4. 링크 연결

# %% [markdown]
# [이름](링크)

# %% [markdown]
# [네이버](https://www.naver.com/)
# [구글](https://www.google.co.kr/)

# %% [markdown]
# ## 5. 이미지

# %% [markdown]
# ![이미지](data:image/jpeg;base64,...)

# %% [markdown]
# ## 6. 코드 블록

# %% [markdown]
# - 인라인 코드(inline code)

# %%
print("hi")
# Out:
# hi

# %% [markdown]
# `print('hi')`

# %% [markdown]
# ```python
# print('hi')
# ```

# %% [markdown]
# ```sql
# select * from table
# ```

# %% [markdown]
# ## 7. 인용문

# %% [markdown]
# > 멋쟁이 사자처럼 AI 개발자 취업!

# %% [markdown]
# ## 8. 수평선

# %% [markdown]
# ---

# %% [markdown]
# # 실습

# %% [markdown]
# ## 개발 블로그

# %% [markdown]
# ### 소개

# %% [markdown]
# 안녕하세요! 😀 **마크다운 문법** 실습입니다. 본인이 관심있는 주제를 잡아 정보를 담아 작성해주세요!

# %% [markdown]
# ### 최신 포스트

# %% [markdown]
# #### 1. 파이썬과 환경설정에 대해 알아봤습니다 🚀

# %% [markdown]
# - [파이썬 환경 이해하기]()

# %% [markdown]
# ```python
# print("hi")
# print("우리 모두 시험 잘봐요")
# ```

# %% [markdown]
# 1. 위와 같은 방식으로 코드를 작성할 수 있습니다.
# 2. 파이썬 파일 확장자는 `python.py` 입니다.
# 3. 그리고 우리는 *JupyterNotebook* 에서 작업을 하고 있습니다.
#     - 대화형 프로그래밍 환경으로, 코드와 문서를 통합하여 작성하고 실행할 수 있는 웹 기반의 인터페이스입니다.
# 4. *JupyterNotebook* 파일 확장자는 `ipython.ipynb` 입니다.

# %% [markdown]
# #### 2. 파이썬으로 데이터를 분석하고, ROS를 사용하자!

# %% [markdown]
# - [파이썬으로 데이터 주무르기]()

# %% [markdown]
# ![이미지1](data:image/jpeg;base64,...)

# %% [markdown]
# - [ROS2 혼자 공부하는 로봇 SW]()

# %% [markdown]
# ![이미지2](data:image/jpeg;base64,...)

# %% [markdown]
# ##### 책소개

# %% [markdown]
# > 이 책은 ROS라는 도구의 존재를 알고 공부하려는 분 중에 아직 공부를 시작하지 않았거나,
# 이것저것 예제를 돌려봤지만 어떤 것인지 감을 잡지 못한 분들을 대상으로 하고 있다.
# 오랫동안 강의를 해왔던 나의 경험을 바탕으로 이러한 독자들이 쉽게 이해할 수 있게 이야기를 들려주는 것처럼 이 책을 기술했다. 이 책이 추구하는 것은 독자들이 빠르게 ROS의 원리와 사용법을 파악해서 하고 싶은 일을 할 수 있도록 하는 것이다.

# %% [markdown]
# ### 3. 파이썬 프로젝트 아이디어 공유

# %% [markdown]
# - [자율주행 로봇 SW 개발 - 차선인식, 장애물 회피, SLAM, ROS2]()

# %% [markdown]
# ##### 블로그에 기여하기

# %% [markdown]
# 프로젝트에 기여하고 싶다면 [GitHub 저장소]()에서 DM 해주세요 🙏

# %% [markdown]
# # 과제

# %% [markdown]
# ## 최신 기술 동향 논문 리뷰 스터디

# %% [markdown]
# ### 0. 들어가며

# %% [markdown]
# 안녕하세요! 🙌 멋사 AI 스쿨 9기 **김효준**이라고 합니다. \
# 소프트웨어를 전공으로 하고 있어서 기존부터 인공지능에 많은 관심을 가져왔고 종종 논문을 보며 최신 기술의 동향을 파악하고 여러 인사이트를 떠올리는 것에 관심이 있었습니다. 이번 기회에 관심이 있는 분들과 함께 최신 기술 동향을 알아가는 스터디를 해보고 싶습니다. 주제에 논문이라고 적어두었지만 최신 기술과 관련된 리뷰면 모두 좋을 것 같아요! 😃

# %% [markdown]
# ### 1. 스터디 소개

# %% [markdown]
# ![논문 리뷰](data:image/jpeg;base64,...)

# %% [markdown]
# 최신 기술 동향 논문 리뷰 스터디는 **NLP(자연어 처리), CV(컴퓨터 비전), Recsys(추천 시스템)** 분야의 SOTA **모델** 리뷰, SOTA **알고리즘** 리뷰, **최신 기술** 리뷰 등 관심 있는 분야의 논문, 아티클, 공식 다큐먼트들을 정리하고 함께 공유하는 스터디입니다.

# %% [markdown]
# ### 2. 방식

# %% [markdown]
# ✅ 주마다 ***하루*** 날짜를 정해서 각자가 정리한 최신 기술 동향을 공유하는 시간을 가져요.
#
# ✔ 기본적으로는 ***비대면***으로 진행할 예정이며, 사는 곳과 시간을 맞출 수 있다면 대면으로 만나도 좋을 것 같아요!
#
# ✅ 블로그나 노션 등 ***개인적인 기록 공간***에 먼저 정리한 후 약속된 날짜에 공유와 발표를 진행해요.
#
# ✔ 이외의 ***규칙***들은 참여자들과 함께 정해볼 예정입니다

# %% [markdown]
# ### 3. 대상

# %% [markdown]
# - 이제 막 인공지능에 관심을 가지기 시작하신 분들, 이미 인공지능에 관심을 가지고 계신 분들 모두 환영합니다!! 🚩
#
# - 예상 인원은 5~6명으로 생각하고 있으니 많은 참여 부탁드립니다! ✋
